# %% [markdown]
# # Normal Vehicle Detection

# %%
# !nvidia-smi
# Out:
# Mon Nov  6 01:44:38 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.105.17   Driver Version: 525.105.17   CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   39C    P8     9W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
import os
HOME = os.getcwd()
print(HOME)
# Out:
# /content

# %% [markdown]
# ## Download

# %%
# !pip install -q gdown
# %cd {HOME}
# !gdown '1IrSdzONaHQnVFFUDqGHxq9T4nu75rBcz'
# Out:
# /content
# Downloading...
# From: https://drive.google.com/uc?id=1IrSdzONaHQnVFFUDqGHxq9T4nu75rBcz
# To: /content/Car.mp4
# 100% 151M/151M [00:02<00:00, 53.6MB/s]

# %%
SOURCE_VIDEO_PATH = "/content/Car.mp4"

# %% [markdown]
# ## Install YOLOv8
#
# If you notice that our notebook behaves incorrectly - especially if you experience errors that prevent you from going through the tutorial - don't hesitate! Let us know and open an [issue](https://github.com/roboflow/notebooks/issues) on the Roboflow Notebooks repository.

# %%
# !pip install ultralytics

from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.207 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 27.2/78.2 GB disk)

# %% [markdown]
# ## Install Roboflow Supervision

# %%
# !pip install supervision

from IPython import display
display.clear_output()

import supervision as sv
print("supervision.__version__:", sv.__version__)
# Out:
# supervision.__version__: 0.16.0

# %% [markdown]
# ## Load pre-trained YOLOv8 model

# %%
MODEL = "yolov8x.pt"

# %%
from ultralytics import YOLO

model = YOLO(MODEL)
model.fuse()
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v0.0.0/yolov8x.pt to 'yolov8x.pt'...
# 100%|██████████| 131M/131M [00:00<00:00, 256MB/s]
# YOLOv8x summary (fused): 268 layers, 68200608 parameters, 0 gradients, 257.8 GFLOPs

# %% [markdown]
# ## Predict and annotate single frame

# %%
# dict maping class_id to class_name
CLASS_NAMES_DICT = model.model.names

# class_ids of interest - car, motorcycle, bus and truck
selected_classes = [2, 3, 5, 7]

# %%
import supervision as sv
import numpy as np

# %%
# create frame generator
generator = sv.get_video_frames_generator(SOURCE_VIDEO_PATH)
# create instance of BoxAnnotator
box_annotator = sv.BoxAnnotator(thickness=2, text_thickness=2, text_scale=1)
# acquire first video frame
iterator = iter(generator)
frame = next(iterator)
# model prediction on single frame and conversion to supervision Detections
results = model(frame, verbose=False)[0]

# convert to Detections
detections = sv.Detections.from_ultralytics(results)
# only consider class id from selected_classes define above
detections = detections[np.isin(detections.class_id, selected_classes)]

# format custom labels
labels = [
    f"{CLASS_NAMES_DICT[class_id]} {confidence:0.2f}"
    for _, _, confidence, class_id, _ in detections
]

# annotate and display frame
anotated_frame=box_annotator.annotate(scene=frame, detections=detections, labels=labels)

# %matplotlib inline
sv.plot_image(anotated_frame, (16,16))

# %% [markdown]
# ## Predict and annotate whole video

# %%
# settings
LINE_START = sv.Point(50, 1500)
LINE_END = sv.Point(3840-50, 1500)

TARGET_VIDEO_PATH = "/content/sample.mp4"

# %%
sv.VideoInfo.from_video_path(SOURCE_VIDEO_PATH)
# Out:
# VideoInfo(width=1920, height=1080, fps=30, total_frames=1776)

# %%
# create BYTETracker instance
byte_tracker = sv.ByteTrack(track_thresh=0.25, track_buffer=30, match_thresh=0.8, frame_rate=30)

# create VideoInfo instance
video_info = sv.VideoInfo.from_video_path(SOURCE_VIDEO_PATH)

# create frame generator
generator = sv.get_video_frames_generator(SOURCE_VIDEO_PATH)

# create LineZone instance, it is previously called LineCounter class
line_zone = sv.LineZone(start=LINE_START, end=LINE_END)

# create instance of BoxAnnotator
box_annotator = sv.BoxAnnotator(thickness=2, text_thickness=2, text_scale=1)

# create instance of TraceAnnotator
trace_annotator = sv.TraceAnnotator(thickness=4, trace_length=50)

# create LineZoneAnnotator instance, it is previously called LineCounterAnnotator class
line_zone_annotator = sv.LineZoneAnnotator(thickness=2, text_thickness=2, text_scale=1)

# define call back function to be used in video processing
def callback(frame: np.ndarray, index:int) -> np.ndarray:
    # model prediction on single frame and conversion to supervision Detections
    results = model(frame, verbose=False)[0]
    detections = sv.Detections.from_ultralytics(results)
    # only consider class id from selected_classes define above
    detections = detections[np.isin(detections.class_id, selected_classes)]
    # tracking detections
    detections = byte_tracker.update_with_detections(detections)
    labels = [
        f"#{tracker_id} {model.model.names[class_id]} {confidence:0.2f}"
        for _, _, confidence, class_id, tracker_id
        in detections
    ]
    annotated_frame = trace_annotator.annotate(
        scene=frame.copy(),
        detections=detections
    )
    annotated_frame=box_annotator.annotate(
        scene=annotated_frame,
        detections=detections,
        labels=labels)

    # update line counter
    line_zone.trigger(detections)
    # return frame with box and line annotated result
    return  line_zone_annotator.annotate(annotated_frame, line_counter=line_zone)

# process the whole video
sv.process_video(
    source_path = SOURCE_VIDEO_PATH,
    target_path = TARGET_VIDEO_PATH,
    callback=callback
)

# %% [markdown]
# # Training Yolov8 for Accident detection

# %%
# !nvidia-smi
# Out:
# Mon Nov  6 01:46:13 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.105.17   Driver Version: 525.105.17   CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   44C    P0    26W /  70W |   1629MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# +-----------------------------------------------------------------------------+

# %%
import os
HOME = os.getcwd()
print(HOME)
# Out:
# /content

# %% [markdown]
# ## Install YOLOv8

# %%
# Pip install method (recommended)

# !pip install ultralytics==8.0.20

from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 27.1/78.2 GB disk)

# %%
from ultralytics import YOLO

from IPython.display import display, Image

# %%
# !mkdir {HOME}/datasets
# %cd {HOME}/datasets

# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="ZD3AXzkhc1x1yNbeAu8I")
project = rf.workspace("accident-detection-ffdrf").project("accident-detection-8dvh5")
dataset = project.version(1).download("yolov8")
# Out:
# mkdir: cannot create directory ‘{HOME}/datasets’: No such file or directory
# [Errno 2] No such file or directory: '{HOME}/datasets'
# /content
# Collecting roboflow
#   Downloading roboflow-1.1.9-py3-none-any.whl (63 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.3/63.3 kB 1.2 MB/s eta 0:00:00
# Requirement already satisfied: certifi==2023.7.22 in /usr/local/lib/python3.10/dist-packages (from roboflow) (2023.7.22)
# Collecting chardet==4.0.0 (from roboflow)
#   Downloading chardet-4.0.0-py2.py3-none-any.whl (178 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.7/178.7 kB 5.4 MB/s eta 0:00:00
# Collecting cycler==0.10.0 (from roboflow)
#   Downloading cycler-0.10.0-py2.py3-none-any.whl (6.5 kB)
# Collecting idna==2.10 (from roboflow)
#   Downloading idna-2.10-py2.py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 5.3 MB/s eta 0:00:00
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.10/dist-packages (from roboflow) (1.4.5)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from roboflow) (3.7.1)
# Requirement already satisfied: numpy>=1.18.5 in /usr/local/lib/python3.10/dist-packages (from roboflow) (1.23.5)
# Collecting opencv-python-headless==4.8.0.74 (from roboflow)
#   Downloading opencv_python_headless-4.8.0.74-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (49.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.1/49.1 MB 15.9 MB/s eta 0:00:00
# Requirement already satisfied: Pillow>=7.1.2 in /usr/local/lib/python3.10/dist-packages (from roboflow) (9.4.0)
# Collecting pyparsing==2.4.7 (from roboflow)
#   Downloading pyparsing-2.4.7-py2.py3-none-any.whl (67 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.8/67.8 kB 6.9 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.10/dist-packages (from roboflow) (2.8.2)
# Collecting python-dotenv (from roboflow)
#   Downloading python_dotenv-1.0.0-py3-none-any.whl (19 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from roboflow) (2.31.0)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from roboflow) (1.16.0)
# Collecting supervision (from roboflow)
#   Downloading supervision-0.16.0-py3-none-any.whl (72 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.2/72.2 kB 7.7 MB/s eta 0:00:00
# Requirement already satisfied: urllib3>=1.26.6 in /usr/local/lib/python3.10/dist-packages (from roboflow) (2.0.7)
# Requirement already satisfied: tqdm>=4.41.0 in /usr/local/lib/python3.10/dist-packages (from roboflow) (4.66.1)
# Requirement already satisfied: PyYAML>=5.3.1 in /usr/local/lib/python3.10/dist-packages (from roboflow) (6.0.1)
# Collecting requests-toolbelt (from roboflow)
#   Downloading requests_toolbelt-1.0.0-py2.py3-none-any.whl (54 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 5.0 MB/s eta 0:00:00
# Collecting python-magic (from roboflow)
#   Downloading python_magic-0.4.27-py2.py3-none-any.whl (13 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->roboflow) (1.1.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->roboflow) (4.43.1)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->roboflow) (23.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->roboflow) (3.3.1)
# Requirement already satisfied: scipy<2.0.0,>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from supervision->roboflow) (1.11.3)
# Installing collected packages: python-magic, python-dotenv, pyparsing, opencv-python-headless, idna, cycler, chardet, supervision, requests-toolbelt, roboflow
#   Attempting uninstall: pyparsing
#     Found existing installation: pyparsing 3.1.1
#     Uninstalling pyparsing-3.1.1:
#       Successfully uninstalled pyparsing-3.1.1
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.8.1.78
#     Uninstalling opencv-python-headless-4.8.1.78:
#       Successfully uninstalled opencv-python-headless-4.8.1.78
#   Attempting uninstall: idna
#     Found existing installation: idna 3.4
#     Uninstalling idna-3.4:
#       Successfully uninstalled idna-3.4
#   Attempting uninstall: cycler
#     Found existing installation: cycler 0.12.1
#     Uninstalling cycler-0.12.1:
#       Successfully uninstalled cycler-0.12.1
#   Attempting uninstall: chardet
#     Found existing installation: chardet 5.2.0
#     Uninstalling chardet-5.2.0:
#       Successfully uninstalled chardet-5.2.0
# Successfully installed chardet-4.0.0 cycler-0.10.0 idna-2.10 opencv-python-headless-4.8.0.74 pyparsing-2.4.7 python-dotenv-1.0.0 python-magic-0.4.27 requests-toolbelt-1.0.0 roboflow-1.1.9 supervision-0.16.0
# loading Roboflow workspace...
# loading Roboflow project...
# [WARNING] we noticed you are downloading a `yolov8` datasets but you don't have `ultralytics` installed. Roboflow `.deploy` supports only models trained with `ultralytics==8.0.196`, to intall it `pip install ultralytics==8.0.196`.
# Downloading Dataset Version Zip in Accident-Detection-1 to yolov8:: 100%|██████████| 923086/923086 [00:26<00:00, 34818.96it/s]
# Extracting Dataset Version Zip to Accident-Detection-1 in yolov8:: 100%|██████████| 23572/23572 [00:07<00:00, 3016.42it/s]

# %% [markdown]
# ## Custom Training

# %%
# !yolo task=detect mode=train model=yolov8n.pt data={dataset.location}/data.yaml epochs=10 imgsz=800 plots=True
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v0.0.0/yolov8n.pt to yolov8n.pt...
# 100% 6.23M/6.23M [00:00<00:00, 77.0MB/s]
#
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# yolo/engine/trainer: task=detect, mode=train, model=yolov8n.yaml, data=/content/datasets/Accident-Detection-1/data.yaml, epochs=10, patience=50, batch=16, imgsz=800, save=True, cache=False, device=, workers=8, project=None, name=None, exist_ok=False, pretrained=False, optimizer=SGD, verbose=True, seed=0, deterministic=True, single_cls=False, image_weights=False, rect=False, cos_lr=False, close_mosaic=10, resume=False, overlap_mask=True, mask_ratio=4, dropout=False, val=True, save_json=False, save_hybrid=False, conf=0.001, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=ultralytics/assets/, show=False, save_txt=False, save_conf=False, save_crop=False, hide_labels=False, hide_conf=False, vid_stride=1, line_thickness=3, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, boxes=True, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=False, opset=17, workspace=4, nms=False, lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.001, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, fl_gamma=0.0, label_smoothing=0.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0, cfg=None, v5loader=False, save_dir=runs/detect/train2
# 2023-11-04 13:56:02.759442: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-11-04 13:56:02.759496: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-11-04 13:56:02.759535: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-11-04 13:56:02.767519: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-11-04 13:56:03.969210: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Overriding model.yaml nc=80 with nc=2
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.Conv                  [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.Conv                  [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.C2f                   [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.Conv                  [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.C2f                   [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.Conv                  [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.C2f                   [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.Conv                  [128, 256, 3, 2]
#   8                  -1  1    460288  ultralytics.nn.modules.C2f                   [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.SPPF                  [256, 256, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.Concat                [1]
#  12                  -1  1    148224  ultralytics.nn.modules.C2f                   [384, 128, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.Concat                [1]
#  15                  -1  1     37248  ultralytics.nn.modules.C2f                   [192, 64, 1]
#  16                  -1  1     36992  ultralytics.nn.modules.Conv                  [64, 64, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.Concat                [1]
#  18                  -1  1    123648  ultralytics.nn.modules.C2f                   [192, 128, 1]
#  19                  -1  1    147712  ultralytics.nn.modules.Conv                  [128, 128, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.Concat                [1]
#  21                  -1  1    493056  ultralytics.nn.modules.C2f                   [384, 256, 1]
#  22        [15, 18, 21]  1    751702  ultralytics.nn.modules.Detect                [2, [64, 128, 256]]
# Model summary: 225 layers, 3011238 parameters, 3011222 gradients, 8.2 GFLOPs
#
# Transferred 319/355 items from pretrained weights
# optimizer: SGD(lr=0.01) with parameter groups 57 weight(decay=0.0), 64 weight(decay=0.001), 63 bias
# train: Scanning /content/datasets/Accident-Detection-1/train/labels.cache... 9758 images, 7 backgrounds, 0 corrupt: 100% 9758/9758 [00:00<?, ?it/s]
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01), CLAHE(p=0.01, clip_limit=(1, 4.0), tile_grid_size=(8, 8))
# val: Scanning /content/datasets/Accident-Detection-1/valid/labels.cache... 1347 images, 1 backgrounds, 0 corrupt: 100% 1347/1347 [00:00<?, ?it/s]
# Image sizes 800 train, 800 val
# Using 2 dataloader workers
# Logging results to runs/detect/train2
# Starting training for 10 epochs...
# Closing dataloader mosaic
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01), CLAHE(p=0.01, clip_limit=(1, 4.0), tile_grid_size=(8, 8))
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/10      3.69G      1.116      2.245      1.667         14        800: 100% 610/610 [04:49<00:00,  2.10it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 43/43 [00:25<00:00,  1.71it/s]
#                    all       1347       1406      0.598      0.563      0.593      0.401
#               moderate       1347        329       0.38      0.553      0.437        0.3
#                 severe       1347       1077      0.815      0.574      0.749      0.501
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/10      4.32G      1.044      1.453      1.585         14        800: 100% 610/610 [04:46<00:00,  2.13it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 43/43 [00:23<00:00,  1.80it/s]
#                    all       1347       1406       0.56      0.541      0.557       0.36
#               moderate       1347        329      0.383      0.456      0.408      0.274
#                 severe       1347       1077      0.738      0.625      0.706      0.446
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/10      4.32G      1.113       1.44      1.645         16        800: 100% 610/610 [04:48<00:00,  2.11it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 43/43 [00:22<00:00,  1.88it/s]
#                    all       1347       1406      0.691      0.536      0.628      0.404
#               moderate       1347        329      0.717       0.37      0.529      0.341
#                 severe       1347       1077      0.664      0.702      0.726      0.468
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/10      4.32G       1.12      1.373      1.651         16        800: 100% 610/610 [04:46<00:00,  2.13it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 43/43 [00:22<00:00,  1.93it/s]
#                    all       1347       1406      0.716      0.545      0.636      0.438
#               moderate       1347        329      0.664      0.385      0.494      0.344
#                 severe       1347       1077      0.767      0.705      0.777      0.531
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        5/10      4.32G      1.056      1.218      1.582         14        800: 100% 610/610 [04:48<00:00,  2.11it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 43/43 [00:23<00:00,  1.82it/s]
#                    all       1347       1406      0.666      0.646      0.698      0.507
#               moderate       1347        329      0.447      0.638      0.562      0.421
#                 severe       1347       1077      0.884      0.653      0.834      0.594
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        6/10      4.32G     0.9575      1.052      1.482         14        800: 100% 610/610 [04:47<00:00,  2.12it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 43/43 [00:23<00:00,  1.81it/s]
#                    all       1347       1406      0.763      0.734      0.796      0.595
#               moderate       1347        329       0.68      0.678      0.721       0.55
#                 severe       1347       1077      0.846       0.79       0.87      0.639
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        7/10      4.32G     0.8651     0.9046      1.388         15        800: 100% 610/610 [04:48<00:00,  2.12it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 43/43 [00:23<00:00,  1.85it/s]
#                    all       1347       1406      0.828      0.771      0.857      0.679
#               moderate       1347        329      0.773      0.681      0.781      0.613
#                 severe       1347       1077      0.882      0.862      0.932      0.744
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        8/10      4.32G      0.773     0.7749      1.302         14        800: 100% 610/610 [04:51<00:00,  2.09it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 43/43 [00:23<00:00,  1.81it/s]
#                    all       1347       1406      0.833      0.814      0.884      0.718
#               moderate       1347        329      0.725      0.778      0.813      0.663
#                 severe       1347       1077      0.941      0.851      0.954      0.773
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        9/10      4.32G     0.7004     0.6561      1.236         14        800: 100% 610/610 [04:48<00:00,  2.12it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 43/43 [00:23<00:00,  1.80it/s]
#                    all       1347       1406      0.892       0.86       0.92      0.773
#               moderate       1347        329      0.865      0.796      0.872      0.734
#                 severe       1347       1077      0.919      0.924      0.969      0.812
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       10/10      4.32G     0.6311     0.5587      1.169         15        800: 100% 610/610 [04:50<00:00,  2.10it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 43/43 [00:28<00:00,  1.53it/s]
#                    all       1347       1406      0.907      0.886      0.941      0.801
#               moderate       1347        329      0.857      0.851      0.905      0.766
#                 severe       1347       1077      0.958      0.922      0.977      0.837
#
# 10 epochs completed in 0.871 hours.
# Optimizer stripped from runs/detect/train2/weights/last.pt, 6.3MB
# Optimizer stripped from runs/detect/train2/weights/best.pt, 6.3MB
#
# Validating runs/detect/train2/weights/best.pt...
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 3006038 parameters, 0 gradients, 8.1 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 43/43 [00:27<00:00,  1.59it/s]
#                    all       1347       1406      0.908      0.885      0.941      0.801
#               moderate       1347        329      0.859      0.851      0.905      0.765
#                 severe       1347       1077      0.957       0.92      0.977      0.837
# Speed: 0.5ms pre-process, 3.2ms inference, 0.0ms loss, 3.2ms post-process per image
# Results saved to runs/detect/train2

# %%
# !ls /content/datasets/runs/detect/train2
# Out:
# args.yaml					    results.csv		   val_batch1_labels.jpg
# confusion_matrix.png				    results.png		   val_batch1_pred.jpg
# events.out.tfevents.1699106165.a367f68a2a70.1638.0  train_batch0.jpg	   val_batch2_labels.jpg
# F1_curve.png					    train_batch1.jpg	   val_batch2_pred.jpg
# P_curve.png					    train_batch2.jpg	   weights
# PR_curve.png					    val_batch0_labels.jpg
# R_curve.png					    val_batch0_pred.jpg

# %%
# %cd {HOME}
Image(filename=f'/content/datasets/runs/detect/train2/confusion_matrix.png', width=600)
# Out:
# /content

# %%
# %cd {HOME}
Image(filename=f'/content/datasets/runs/detect/train2/results.png', width=600)
# Out:
# /content

# %%
# %cd {HOME}
Image(filename=f'/content/datasets/runs/detect/train2/val_batch0_pred.jpg', width=600)
# Out:
# /content

# %% [markdown]
# ## Validate Custom Model

# %%
# %cd {HOME}

# !yolo task=detect mode=val model=/content/datasets/runs/detect/train2/weights/best.pt data={dataset.location}/data.yaml
# Out:
# /content
# 2023-11-04 15:13:20.624954: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-11-04 15:13:20.625020: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-11-04 15:13:20.625068: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-11-04 15:13:20.638324: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-11-04 15:13:22.515411: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 3006038 parameters, 0 gradients, 8.1 GFLOPs
# val: Scanning /content/datasets/Accident-Detection-1/valid/labels.cache... 1347 images, 1 backgrounds, 0 corrupt: 100% 1347/1347 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 85/85 [00:24<00:00,  3.44it/s]
#                    all       1347       1406      0.908      0.886      0.941      0.801
#               moderate       1347        329      0.858      0.851      0.905      0.766
#                 severe       1347       1077      0.958      0.921      0.977      0.837
# Speed: 0.8ms pre-process, 5.6ms inference, 0.0ms loss, 2.3ms post-process per image

# %% [markdown]
# ## Inference with Custom Model

# %%
# %cd {HOME}
# !yolo task=detect mode=predict model=/content/datasets/runs/detect/train2/weights/best.pt conf=0.25 source={dataset.location}/test/images save=True
# Out:
# /content
# 2023-11-04 15:14:12.115716: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-11-04 15:14:12.115775: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-11-04 15:14:12.115814: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-11-04 15:14:12.123837: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-11-04 15:14:13.550240: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 3006038 parameters, 0 gradients, 8.1 GFLOPs
# image 1/675 /content/datasets/Accident-Detection-1/test/images/10-79_jpg.rf.c8c45a84e257a0982992784c79d52e5a.jpg: 800x800 1 moderate, 10.0ms
# image 2/675 /content/datasets/Accident-Detection-1/test/images/1042_jpeg_jpg.rf.7e3a9690d440a3b40b11960110295ab7.jpg: 800x800 2 severes, 11.2ms
# image 3/675 /content/datasets/Accident-Detection-1/test/images/1042_jpeg_jpg.rf.86d1710c51d86a436ae5013b6f2b8dcf.jpg: 800x800 2 severes, 9.9ms
# image 4/675 /content/datasets/Accident-Detection-1/test/images/1080_jpeg_jpg.rf.b6e9598c80730f1a88160a340a981bea.jpg: 800x800 1 severe, 9.9ms
# image 5/675 /content/datasets/Accident-Detection-1/test/images/1083_jpeg_jpg.rf.7fffdb28eac8f2b4dfcc0c636bf5ded8.jpg: 800x800 1 severe, 9.9ms
# image 6/675 /content/datasets/Accident-Detection-1/test/images/14-169_jpg.rf.92b49386a161e1a0da27c81097c303e1.jpg: 800x800 1 severe, 9.9ms
# image 7/675 /content/datasets/Accident-Detection-1/test/images/14-17_jpg.rf.2bf683f68693e53ac8c447f2d5d59daa.jpg: 800x800 1 severe, 9.9ms
# image 8/675 /content/datasets/Accident-Detection-1/test/images/14-29_jpg.rf.dad071831cd088c8a90790a86ee3b73a.jpg: 800x800 1 severe, 9.9ms
# image 9/675 /content/datasets/Accident-Detection-1/test/images/14-40_jpg.rf.659f547466403c438d2384ce140ad842.jpg: 800x800 1 severe, 9.9ms
# image 10/675 /content/datasets/Accident-Detection-1/test/images/168_jpeg_jpg.rf.613df209d6b2e7049ccff709617e4352.jpg: 800x800 1 severe, 9.9ms
# image 11/675 /content/datasets/Accident-Detection-1/test/images/170_jpeg_jpg.rf.4fdf16286223f71855b851a3a7c3f3ec.jpg: 800x800 1 severe, 9.9ms
# image 12/675 /content/datasets/Accident-Detection-1/test/images/170_jpeg_jpg.rf.935a0a238ca70b4487cd48562495b7f8.jpg: 800x800 1 severe, 9.9ms
# image 13/675 /content/datasets/Accident-Detection-1/test/images/170_jpeg_jpg.rf.ad816d903bff5e609059204eae540950.jpg: 800x800 1 severe, 9.9ms
# image 14/675 /content/datasets/Accident-Detection-1/test/images/2-16_jpg.rf.25466b676d388f33d0ecb170e2878c79.jpg: 800x800 2 moderates, 9.9ms
# image 15/675 /content/datasets/Accident-Detection-1/test/images/2-16_jpg.rf.42fe0c36f7b1eebc25d6d7022e38b790.jpg: 800x800 2 moderates, 9.9ms
# image 16/675 /content/datasets/Accident-Detection-1/test/images/2-34_jpg.rf.1768d4cd110929df6c56459ecd809276.jpg: 800x800 1 moderate, 9.9ms
# image 17/675 /content/datasets/Accident-Detection-1/test/images/2-34_jpg.rf.9e82af840df08388d46993bcf39cbbd3.jpg: 800x800 1 moderate, 9.9ms
# image 18/675 /content/datasets/Accident-Detection-1/test/images/2-34_jpg.rf.d976f03dc99797a75ef453fd4168fb5b.jpg: 800x800 1 moderate, 9.9ms
# image 19/675 /content/datasets/Accident-Detection-1/test/images/2-8_jpg.rf.ebf4cdc8ab1e7991aa874f3966067877.jpg: 800x800 1 moderate, 1 severe, 9.9ms
# image 20/675 /content/datasets/Accident-Detection-1/test/images/25641839_web1_210627-GNG-millstream-accident-_1_jpg.rf.22fed94f2ec6b496015d853016378d21.jpg: 800x800 1 moderate, 9.9ms
# image 21/675 /content/datasets/Accident-Detection-1/test/images/25641839_web1_210627-GNG-millstream-accident-_1_jpg.rf.6f367c1648429a42e32fb73908bf427f.jpg: 800x800 1 moderate, 9.9ms
# image 22/675 /content/datasets/Accident-Detection-1/test/images/25641839_web1_210627-GNG-millstream-accident-_1_jpg.rf.eb7e23be48cdb39afe9fb22f66910bc7.jpg: 800x800 1 moderate, 9.9ms
# image 23/675 /content/datasets/Accident-Detection-1/test/images/2Q__-10-_jpg.rf.70b6ba0c45f74c8a9e175aa9edbb6f63.jpg: 800x800 1 severe, 9.9ms
# image 24/675 /content/datasets/Accident-Detection-1/test/images/2Q__-10-_jpg.rf.f582826a2112855924cde164d5c56473.jpg: 800x800 1 severe, 9.9ms
# image 25/675 /content/datasets/Accident-Detection-1/test/images/2Q__-6-_jpg.rf.005d23959a5c7203bc03d5901e6f1cc7.jpg: 800x800 1 severe, 9.9ms
# image 26/675 /content/datasets/Accident-Detection-1/test/images/4-105_jpg.rf.a603852c96a7232f439fbb50c7c43060.jpg: 800x800 1 moderate, 9.9ms
# image 27/675 /content/datasets/Accident-Detection-1/test/images/4-10_jpg.rf.c046c1a85c2f7edbd3639fa922fca921.jpg: 800x800 1 moderate, 1 severe, 9.9ms
# image 28/675 /content/datasets/Accident-Detection-1/test/images/4-27_jpg.rf.e8af3c7e868495d23ae02a43c0155cda.jpg: 800x800 1 moderate, 9.9ms
# image 29/675 /content/datasets/Accident-Detection-1/test/images/4-7_jpg.rf.c2eb8e316e88c148b27d2f5164d881a4.jpg: 800x800 1 severe, 9.9ms
# image 30/675 /content/datasets/Accident-Detection-1/test/images/4139_jpeg_jpg.rf.5fe5ec42e04069b42eca820e28b21438.jpg: 800x800 9.9ms
# image 31/675 /content/datasets/Accident-Detection-1/test/images/5895211_013120-skyeye-garbage-truck-vid_jpg.rf.d29170741a62f2829a99a8a7f7409115.jpg: 800x800 1 severe, 9.9ms
# image 32/675 /content/datasets/Accident-Detection-1/test/images/755_jpeg_jpg.rf.d8ccaf7b4f8332f183c410a89e3189a0.jpg: 800x800 1 moderate, 9.9ms
# image 33/675 /content/datasets/Accident-Detection-1/test/images/756_jpeg_jpg.rf.61792601f76d0810bccb6f19a35efe80.jpg: 800x800 1 moderate, 9.9ms
# image 34/675 /content/datasets/Accident-Detection-1/test/images/756_jpeg_jpg.rf.a6a89677480878b82ae137f391ec7e67.jpg: 800x800 1 moderate, 9.9ms
# image 35/675 /content/datasets/Accident-Detection-1/test/images/779_jpeg_jpg.rf.2cb1c9249b4bf40e179780db06aaf9f7.jpg: 800x800 1 severe, 9.9ms
# image 36/675 /content/datasets/Accident-Detection-1/test/images/788_jpeg_jpg.rf.08d94ba2c6135b85ca32f007eb978256.jpg: 800x800 2 moderates, 9.9ms
# image 37/675 /content/datasets/Accident-Detection-1/test/images/788_jpeg_jpg.rf.0bbb67cf7b17114454397e9cfc1d9c77.jpg: 800x800 2 moderates, 9.9ms
# image 38/675 /content/datasets/Accident-Detection-1/test/images/788_jpeg_jpg.rf.a4b74f9df9b164d82708e61f7fca1e31.jpg: 800x800 1 moderate, 9.9ms
# image 39/675 /content/datasets/Accident-Detection-1/test/images/799_jpeg_jpg.rf.1ec70575e609a9fa65da4b402feb2fa3.jpg: 800x800 1 moderate, 9.9ms
# image 40/675 /content/datasets/Accident-Detection-1/test/images/801_jpeg_jpg.rf.510a4f5d5da560de13c5f02ebcd5f573.jpg: 800x800 1 moderate, 1 severe, 10.8ms
# image 41/675 /content/datasets/Accident-Detection-1/test/images/809_jpeg_jpg.rf.9cae1ad27f954c69ea4641e1b8edf927.jpg: 800x800 1 severe, 14.0ms
# image 42/675 /content/datasets/Accident-Detection-1/test/images/809_jpeg_jpg.rf.dd3a33a056cece27f070b96aa6d9c5ed.jpg: 800x800 1 severe, 9.9ms
# image 43/675 /content/datasets/Accident-Detection-1/test/images/820_jpeg_jpg.rf.c824eb5f9aca8bd6da9fbb11933c0b96.jpg: 800x800 1 severe, 9.9ms
# image 44/675 /content/datasets/Accident-Detection-1/test/images/825_jpeg_jpg.rf.a42e4d75350c71ed726042379126fc58.jpg: 800x800 1 moderate, 9.9ms
# image 45/675 /content/datasets/Accident-Detection-1/test/images/841_jpeg_jpg.rf.9ccf0df0f79fc3c96e6f1e4ea1bc94ef.jpg: 800x800 1 moderate, 9.9ms
# image 46/675 /content/datasets/Accident-Detection-1/test/images/905_jpeg_jpg.rf.95a52327d19734a4688245c97a93cdd8.jpg: 800x800 1 moderate, 9.9ms
# image 47/675 /content/datasets/Accident-Detection-1/test/images/909_jpeg_jpg.rf.d53de5de0633288e0fb6b20b769826fd.jpg: 800x800 1 moderate, 9.9ms
# image 48/675 /content/datasets/Accident-Detection-1/test/images/946_jpeg_jpg.rf.4c8e1e0b3a7bfa28fc907f8f07b9b3ad.jpg: 800x800 1 moderate, 9.9ms
# image 49/675 /content/datasets/Accident-Detection-1/test/images/981_jpeg_jpg.rf.84070954c602918f0e4e7e58095870fe.jpg: 800x800 1 moderate, 1 severe, 9.9ms
# image 50/675 /content/datasets/Accident-Detection-1/test/images/AD1_jpeg_jpg.rf.e8d0d6f46c470310598157473554308c.jpg: 800x800 1 moderate, 9.9ms
# image 51/675 /content/datasets/Accident-Detection-1/test/images/Abu-Dhabi-accident-CCTV-_16d80b9b401_large_jpg.rf.12e012ccf7798763a523f7f407df4069.jpg: 800x800 1 moderate, 9.9ms
# image 52/675 /content/datasets/Accident-Detection-1/test/images/B398337C-A51B-4978-AD2D-1D4C577226D7-e1648925924652_jpg.rf.89b5171f73d0e501595d910f64dbb0ed.jpg: 800x800 1 severe, 9.9ms
# image 53/675 /content/datasets/Accident-Detection-1/test/images/B398337C-A51B-4978-AD2D-1D4C577226D7-e1648925924652_jpg.rf.ee47ca199515160d7d20894a84651a24.jpg: 800x800 1 severe, 9.9ms
# image 54/675 /content/datasets/Accident-Detection-1/test/images/FLIP_CAR_V110_jpg.rf.c10d5a8188cc23b4b1c4d8be373858f3.jpg: 800x800 1 severe, 9.9ms
# image 55/675 /content/datasets/Accident-Detection-1/test/images/FLIP_CAR_V111_jpg.rf.17f145e6bb5a8dcef505a3dbc5b45559.jpg: 800x800 1 severe, 9.9ms
# image 56/675 /content/datasets/Accident-Detection-1/test/images/FLIP_CAR_V112_jpg.rf.52a487f3793a6fa934ab780a2ca0622e.jpg: 800x800 1 severe, 10.0ms
# image 57/675 /content/datasets/Accident-Detection-1/test/images/FLIP_CAR_V115_jpg.rf.9e7b981f5628da73079c7791075d373f.jpg: 800x800 1 severe, 9.9ms
# image 58/675 /content/datasets/Accident-Detection-1/test/images/FLIP_CAR_V116_jpg.rf.2d2a27d4110ba48ca30780f41726c535.jpg: 800x800 1 severe, 9.9ms
# image 59/675 /content/datasets/Accident-Detection-1/test/images/FLIP_CAR_V116_jpg.rf.64eacbc8f003a7bf0c42abf85d2e2ec1.jpg: 800x800 1 severe, 9.9ms
# image 60/675 /content/datasets/Accident-Detection-1/test/images/FLIP_CAR_V119_jpg.rf.119664ed0a436f8cb09e51296096e84f.jpg: 800x800 2 severes, 9.9ms
# image 61/675 /content/datasets/Accident-Detection-1/test/images/FLIP_CAR_V119_jpg.rf.859291b497ca20c522b9042f49fd0552.jpg: 800x800 2 severes, 9.9ms
# image 62/675 /content/datasets/Accident-Detection-1/test/images/FLIP_CAR_V11_jpg.rf.e7370c7358ecd1d52c404b8722af8090.jpg: 800x800 1 severe, 9.9ms
# image 63/675 /content/datasets/Accident-Detection-1/test/images/FLIP_CAR_V121_jpg.rf.92e8e4d57558fb9a3d601094ff9b25f1.jpg: 800x800 2 severes, 9.9ms
# image 64/675 /content/datasets/Accident-Detection-1/test/images/FLIP_CAR_V123_jpg.rf.7ad0379442cb128aef8f428cf223c98a.jpg: 800x800 1 severe, 9.9ms
# image 65/675 /content/datasets/Accident-Detection-1/test/images/FLIP_CAR_V129_jpg.rf.08d4d2c8223a974d0382f75fa654cfe4.jpg: 800x800 1 severe, 9.9ms
# image 66/675 /content/datasets/Accident-Detection-1/test/images/FLIP_CAR_V130_jpg.rf.f7125a1d7a01a7830877dc8b83d0163c.jpg: 800x800 2 severes, 9.9ms
# image 67/675 /content/datasets/Accident-Detection-1/test/images/FLIP_CAR_V135_jpg.rf.5d852c86f5a58c7c66a9fb8e55f39fce.jpg: 800x800 1 severe, 9.9ms
# image 68/675 /content/datasets/Accident-Detection-1/test/images/FLIP_CAR_V136_jpg.rf.14e149c14efe57ebcba471264f8ab4c2.jpg: 800x800 1 severe, 9.9ms
# image 69/675 /content/datasets/Accident-Detection-1/test/images/FLIP_CAR_V137_jpg.rf.70d93a0a92a17caaef2555310fc1d61c.jpg: 800x800 1 severe, 9.9ms
# image 70/675 /content/datasets/Accident-Detection-1/test/images/FLIP_CAR_V138_jpg.rf.7e05a711279e119ae933381f99b0ce89.jpg: 800x800 1 severe, 9.9ms
# image 71/675 /content/datasets/Accident-Detection-1/test/images/FLIP_CAR_V13_jpg.rf.3ab37a36f289ad3506f37bc8242a3b77.jpg: 800x800 3 severes, 9.9ms
# image 72/675 /content/datasets/Accident-Detection-1/test/images/FLIP_CAR_V13_jpg.rf.a0f9edeeb807848647f87f5df337b41d.jpg: 800x800 3 severes, 9.9ms
# image 73/675 /content/datasets/Accident-Detection-1/test/images/FLIP_CAR_V141_jpg.rf.3358b813b81040ad062e92ca31b3c8eb.jpg: 800x800 1 severe, 9.9ms
# image 74/675 /content/datasets/Accident-Detection-1/test/images/FLIP_CAR_V142_jpg.rf.6bbbc50037130e9c87680c1a30beb6f7.jpg: 800x800 1 severe, 9.9ms
# image 75/675 /content/datasets/Accident-Detection-1/test/images/FLIP_CAR_V143_jpg.rf.3258d3833cad619847c091a7da5897ac.jpg: 800x800 1 severe, 9.9ms
# image 76/675 /content/datasets/Accident-Detection-1/test/images/FLIP_CAR_V148_jpg.rf.8ca78fdee87295152778f2e8f25d1a7f.jpg: 800x800 1 severe, 10.1ms
# image 77/675 /content/datasets/Accident-Detection-1/test/images/FLIP_CAR_V152_jpg.rf.aa4dac78857a3d5de4c017271310c2b0.jpg: 800x800 1 severe, 9.9ms
# image 78/675 /content/datasets/Accident-Detection-1/test/images/FLIP_CAR_V152_jpg.rf.b7b5a2925637f3cab8e771042134f5c2.jpg: 800x800 1 severe, 9.9ms
# image 79/675 /content/datasets/Accident-Detection-1/test/images/FLIP_CAR_V153_jpg.rf.c71283cb80405bb97a0635adcffc199f.jpg: 800x800 1 severe, 9.9ms
# image 80/675 /content/datasets/Accident-Detection-1/test/images/FLIP_CAR_V158_jpg.rf.dce6cc4b2d985b69bb47377dc139c581.jpg: 800x800 1 severe, 9.9ms
# image 81/675 /content/datasets/Accident-Detection-1/test/images/FLIP_CAR_V161_jpg.rf.28698c429d012fd50ba52797232867f0.jpg: 800x800 1 moderate, 9.9ms
# image 82/675 /content/datasets/Accident-Detection-1/test/images/FLIP_CAR_V161_jpg.rf.5bfc1bbbf856732ccc3278735cea6316.jpg: 800x800 1 moderate, 9.9ms
# image 83/675 /content/datasets/Accident-Detection-1/test/images/FLIP_CAR_V162_jpg.rf.0d4f240dc14456c3fea7de8abfc931b6.jpg: 800x800 1 severe, 9.9ms
# image 84/675 /content/datasets/Accident-Detection-1/test/images/FLIP_CAR_V163_jpg.rf.3d62897ec91ba3f2b4121d57c45555ea.jpg: 800x800 1 severe, 9.9ms
# image 85/675 /content/datasets/Accident-Detection-1/test/images/FLIP_CAR_V163_jpg.rf.662770ff58d3b2a9a96e3c7823870440.jpg: 800x800 1 severe, 9.9ms
# image 86/675 /content/datasets/Accident-Detection-1/test/images/FLIP_CAR_V164_jpg.rf.e48e6c00636057d221214b379d15746a.jpg: 800x800 1 severe, 9.9ms
# image 87/675 /content/datasets/Accident-Detection-1/test/images/FLIP_CAR_V165_jpg.rf.798b78f40d4fb60feb7d793148f68813.jpg: 800x800 1 severe, 9.9ms
# image 88/675 /content/datasets/Accident-Detection-1/test/images/FLIP_CAR_V166_jpg.rf.4feb83cf3959605563c422b14b75a8c6.jpg: 800x800 1 severe, 9.9ms
# image 89/675 /content/datasets/Accident-Detection-1/test/images/FLIP_CAR_V168_jpg.rf.263163d221a2fa609955e234fee0bb7d.jpg: 800x800 1 severe, 9.9ms
# image 90/675 /content/datasets/Accident-Detection-1/test/images/FLIP_CAR_V172_jpg.rf.af4a5bff05f17eedbae92cdfa5697648.jpg: 800x800 2 severes, 9.9ms
# image 91/675 /content/datasets/Accident-Detection-1/test/images/FLIP_CAR_V172_jpg.rf.b8767b9e55fb5da3b13f587efc707ec4.jpg: 800x800 2 severes, 9.9ms
# image 92/675 /content/datasets/Accident-Detection-1/test/images/FLIP_CAR_V17_jpg.rf.1c125016b301ff7035f1ab5329f7937b.jpg: 800x800 1 moderate, 1 severe, 9.9ms
# image 93/675 /content/datasets/Accident-Detection-1/test/images/FLIP_CAR_V18_jpg.rf.ec87f7785436e0dde391aabe5b382da4.jpg: 800x800 1 severe, 9.9ms
# image 94/675 /content/datasets/Accident-Detection-1/test/images/LakeStevens_Fatal_jpg.rf.59e82bb4866288ac1205c8cdeebd8fbe.jpg: 800x800 2 moderates, 9.9ms
# image 95/675 /content/datasets/Accident-Detection-1/test/images/LakeStevens_Fatal_jpg.rf.6ce02e3bcb0c154ea51d348e46f9f436.jpg: 800x800 2 moderates, 1 severe, 9.9ms
# image 96/675 /content/datasets/Accident-Detection-1/test/images/Semi-RealisticVD-119_jpg.rf.cd56f14e45ec79246ede8841d5f245e6.jpg: 800x800 1 moderate, 9.9ms
# image 97/675 /content/datasets/Accident-Detection-1/test/images/Semi-RealisticVD-11_jpg.rf.6a33a400af47d0b3cdca84ff93d38bb5.jpg: 800x800 1 moderate, 1 severe, 9.9ms
# image 98/675 /content/datasets/Accident-Detection-1/test/images/Semi-RealisticVD-11_jpg.rf.7e908e4e1be94c215ccfc5b9de04fddd.jpg: 800x800 1 moderate, 1 severe, 9.9ms
# image 99/675 /content/datasets/Accident-Detection-1/test/images/Semi-RealisticVD-11_jpg.rf.ae1f460d6d0a5ec9dbf098917c5b7925.jpg: 800x800 1 moderate, 1 severe, 9.9ms
# image 100/675 /content/datasets/Accident-Detection-1/test/images/Semi-RealisticVD-11_jpg.rf.c6b89931cd7ab15d34a22c62244af4f0.jpg: 800x800 1 moderate, 9.9ms
# image 101/675 /content/datasets/Accident-Detection-1/test/images/Semi-RealisticVD-12_jpg.rf.cd75446db382c4d5124dcfbf8a9348e0.jpg: 800x800 1 moderate, 9.9ms
# image 102/675 /content/datasets/Accident-Detection-1/test/images/Semi-RealisticVD-132_jpg.rf.fd1d7182945fca7f032a321f0a154048.jpg: 800x800 1 moderate, 9.9ms
# image 103/675 /content/datasets/Accident-Detection-1/test/images/Semi-RealisticVD-143_jpg.rf.94668ba820ca593c8775bb4e7f46bf92.jpg: 800x800 3 moderates, 9.9ms
# image 104/675 /content/datasets/Accident-Detection-1/test/images/Semi-RealisticVD-143_jpg.rf.b8b092aeacb4ffea7bd33bed03c47a5c.jpg: 800x800 3 moderates, 9.9ms
# image 105/675 /content/datasets/Accident-Detection-1/test/images/Semi-RealisticVD-148_jpg.rf.222614c85c28a7a351232aa2e7287737.jpg: 800x800 1 moderate, 9.9ms
# image 106/675 /content/datasets/Accident-Detection-1/test/images/Semi-RealisticVD-157_jpg.rf.1d87351552f682c78e3a62d46ca87650.jpg: 800x800 1 severe, 10.9ms
# image 107/675 /content/datasets/Accident-Detection-1/test/images/Semi-RealisticVD-174_jpg.rf.5c979f21f40e2e43a1a4a8325f245a0d.jpg: 800x800 1 moderate, 9.9ms
# image 108/675 /content/datasets/Accident-Detection-1/test/images/Semi-RealisticVD-176_jpg.rf.c8b4e73be7e8cd84f51f340dc34a1d9a.jpg: 800x800 1 moderate, 9.9ms
# image 109/675 /content/datasets/Accident-Detection-1/test/images/Semi-RealisticVD-180_jpg.rf.6898c993c75064ee50d9c025943ddeff.jpg: 800x800 1 severe, 9.9ms
# image 110/675 /content/datasets/Accident-Detection-1/test/images/Semi-RealisticVD-190_jpg.rf.556fca4a9ab4e050d64d49341eac4cc2.jpg: 800x800 1 moderate, 9.9ms
# image 111/675 /content/datasets/Accident-Detection-1/test/images/Semi-RealisticVD-190_jpg.rf.607807a1f4d41217d3c678c9a28e4d99.jpg: 800x800 1 moderate, 9.9ms
# image 112/675 /content/datasets/Accident-Detection-1/test/images/Semi-RealisticVD-195_jpg.rf.2ea145b57cbab0817770c42adf074b2a.jpg: 800x800 1 severe, 9.9ms
# image 113/675 /content/datasets/Accident-Detection-1/test/images/Semi-RealisticVD-195_jpg.rf.c7576f0e5b0ac08c0fd57770c224d949.jpg: 800x800 1 severe, 9.9ms
# image 114/675 /content/datasets/Accident-Detection-1/test/images/Semi-RealisticVD-203_jpg.rf.1407e515753547313b3d94a13061e85c.jpg: 800x800 1 moderate, 9.9ms
# image 115/675 /content/datasets/Accident-Detection-1/test/images/Semi-RealisticVD-203_jpg.rf.38e016878ea312dde1903ab438405a8e.jpg: 800x800 1 moderate, 9.9ms
# image 116/675 /content/datasets/Accident-Detection-1/test/images/Semi-RealisticVD-20_jpg.rf.c27392c5159da911b47364f417f5d091.jpg: 800x800 2 severes, 9.9ms
# image 117/675 /content/datasets/Accident-Detection-1/test/images/Semi-RealisticVD-216_jpg.rf.8ac9e61f21ce6cd9e2ba4d2962118dfa.jpg: 800x800 1 moderate, 9.9ms
# image 118/675 /content/datasets/Accident-Detection-1/test/images/Semi-RealisticVD-216_jpg.rf.bbe1cc629792c4a9990ca7f736df9fc3.jpg: 800x800 1 moderate, 9.9ms
# image 119/675 /content/datasets/Accident-Detection-1/test/images/Semi-RealisticVD-224_jpg.rf.6eddff0c8981de33d76ab01482c5c51e.jpg: 800x800 1 moderate, 9.9ms
# image 120/675 /content/datasets/Accident-Detection-1/test/images/Semi-RealisticVD-224_jpg.rf.9adbbb6762c19153ce66ac61547d0cee.jpg: 800x800 1 moderate, 9.9ms
# image 121/675 /content/datasets/Accident-Detection-1/test/images/Semi-RealisticVD-232_jpg.rf.6e27b39d90f6fdaa1a1591df20119d28.jpg: 800x800 1 moderate, 9.9ms
# image 122/675 /content/datasets/Accident-Detection-1/test/images/Semi-RealisticVD-26_jpg.rf.56f7577c068e5b2f3ca4c734d7548ad4.jpg: 800x800 2 moderates, 9.9ms
# image 123/675 /content/datasets/Accident-Detection-1/test/images/Semi-RealisticVD-29_jpg.rf.0b6facc7499dc3775c2e1c82994717d0.jpg: 800x800 1 moderate, 9.9ms
# image 124/675 /content/datasets/Accident-Detection-1/test/images/Semi-RealisticVD-29_jpg.rf.8de98b493bd7a08f6401d63b30e81c0d.jpg: 800x800 1 moderate, 9.9ms
# image 125/675 /content/datasets/Accident-Detection-1/test/images/Semi-RealisticVD-31_jpg.rf.317b4cf82a2b0bff29fe9f6e76f584f8.jpg: 800x800 1 moderate, 9.9ms
# image 126/675 /content/datasets/Accident-Detection-1/test/images/Semi-RealisticVD-32_jpg.rf.a9a4df4c769a6b0d3df9d521bf6252b2.jpg: 800x800 1 moderate, 10.0ms
# image 127/675 /content/datasets/Accident-Detection-1/test/images/Semi-RealisticVD-45_jpg.rf.b76b79a83d66aaa0189baf8657cb67d3.jpg: 800x800 1 moderate, 9.9ms
# image 128/675 /content/datasets/Accident-Detection-1/test/images/Semi-RealisticVD-49_jpg.rf.15849fd213d3f8e77015023a34442741.jpg: 800x800 1 moderate, 9.9ms
# image 129/675 /content/datasets/Accident-Detection-1/test/images/Semi-RealisticVD-49_jpg.rf.fedd14f5998e3cca0e7e527cd81a2977.jpg: 800x800 1 moderate, 9.9ms
# image 130/675 /content/datasets/Accident-Detection-1/test/images/Semi-RealisticVD-52_jpg.rf.8c3a76f99925db4917ce2b83519be849.jpg: 800x800 1 severe, 9.9ms
# image 131/675 /content/datasets/Accident-Detection-1/test/images/Semi-RealisticVD-55_jpg.rf.36957443b2eac8d6b01c98f6b3f7df22.jpg: 800x800 1 moderate, 9.9ms
# image 132/675 /content/datasets/Accident-Detection-1/test/images/Severity_Detect_V11_jpg.rf.267a34ac62598e903293d55740d6cf36.jpg: 800x800 1 moderate, 1 severe, 9.9ms
# image 133/675 /content/datasets/Accident-Detection-1/test/images/Severity_Detect_V11_jpg.rf.26c27aefe14638b8aea1fbdc509233b6.jpg: 800x800 1 moderate, 9.9ms
# image 134/675 /content/datasets/Accident-Detection-1/test/images/Severity_Detect_V11_jpg.rf.81cc414abedfe0f88dce6d63fd3a274f.jpg: 800x800 1 moderate, 1 severe, 9.9ms
# image 135/675 /content/datasets/Accident-Detection-1/test/images/Severity_Detect_V14_jpg.rf.a8f54deb81f600152deb7b5d35e83f37.jpg: 800x800 1 severe, 9.9ms
# image 136/675 /content/datasets/Accident-Detection-1/test/images/Severity_Detect_V16_jpg.rf.b3ed2340fa538c5d2ea2680fe31cee32.jpg: 800x800 1 severe, 9.9ms
# image 137/675 /content/datasets/Accident-Detection-1/test/images/Severity_Detect_V17_jpg.rf.627acb73e27495fd90b6c2dff9660aee.jpg: 800x800 1 severe, 10.0ms
# image 138/675 /content/datasets/Accident-Detection-1/test/images/Severity_Detect_V1_jpg.rf.7cf70e485857e50e89938da1f3b5fb14.jpg: 800x800 1 severe, 9.9ms
# image 139/675 /content/datasets/Accident-Detection-1/test/images/Severity_Detect_V22_jpg.rf.cc94653d4bd6006fd313212fe7ff054a.jpg: 800x800 1 severe, 9.9ms
# image 140/675 /content/datasets/Accident-Detection-1/test/images/Severity_Detect_V23_jpg.rf.0bcf2306d668fa34ecf811b02e9fdfea.jpg: 800x800 1 moderate, 10.0ms
# image 141/675 /content/datasets/Accident-Detection-1/test/images/Severity_Detect_V23_jpg.rf.f0d2e43ae234a5809364886c7fa2b6bb.jpg: 800x800 1 moderate, 9.9ms
# image 142/675 /content/datasets/Accident-Detection-1/test/images/Severity_Detect_V25_jpg.rf.2278c0fb94531359f2a73959f0e352fd.jpg: 800x800 1 severe, 9.9ms
# image 143/675 /content/datasets/Accident-Detection-1/test/images/Severity_Detect_V26_jpg.rf.e6a312f6a568ed8ee7afdba505ae2216.jpg: 800x800 1 severe, 9.9ms
# image 144/675 /content/datasets/Accident-Detection-1/test/images/Severity_Detect_V27_jpg.rf.4b360323ab491e7af64312c10014dc3a.jpg: 800x800 1 severe, 10.0ms
# image 145/675 /content/datasets/Accident-Detection-1/test/images/Severity_Detect_V27_jpg.rf.6c62a9929953fe8908bcc56d451b4ea1.jpg: 800x800 1 severe, 9.9ms
# image 146/675 /content/datasets/Accident-Detection-1/test/images/Severity_Detect_V29_jpg.rf.a5f5037103d5718f8575ad9d14b6ee16.jpg: 800x800 1 severe, 9.9ms
# image 147/675 /content/datasets/Accident-Detection-1/test/images/Severity_Detect_V2_jpg.rf.ce1ab5118443c43e84a5a71effa013a2.jpg: 800x800 1 moderate, 1 severe, 9.9ms
# image 148/675 /content/datasets/Accident-Detection-1/test/images/Severity_Detect_V31_jpg.rf.74f985e117f54bb92f5757c06279fa21.jpg: 800x800 1 severe, 9.9ms
# image 149/675 /content/datasets/Accident-Detection-1/test/images/Severity_Detect_V35_jpg.rf.03fa951e6cbd8508340e99c39a3ee6a2.jpg: 800x800 1 severe, 9.9ms
# image 150/675 /content/datasets/Accident-Detection-1/test/images/Severity_Detect_V36_jpg.rf.68467cc11563cd12a080437a258280ef.jpg: 800x800 1 severe, 9.9ms
# image 151/675 /content/datasets/Accident-Detection-1/test/images/Severity_Detect_V36_jpg.rf.a2341550b44e3f2e4b26251b1b12f0fa.jpg: 800x800 1 severe, 10.0ms
# image 152/675 /content/datasets/Accident-Detection-1/test/images/Severity_Detect_V39_jpg.rf.8e023cf04c05f29867c7cfa757e4990b.jpg: 800x800 1 severe, 9.9ms
# image 153/675 /content/datasets/Accident-Detection-1/test/images/Severity_Detect_V40_jpg.rf.3447d731825a04c091a08e27bae5e1f6.jpg: 800x800 1 severe, 9.9ms
# image 154/675 /content/datasets/Accident-Detection-1/test/images/Severity_Detect_V5_jpg.rf.8c02f20b73b7396f819970103199f56b.jpg: 800x800 1 severe, 9.9ms
# image 155/675 /content/datasets/Accident-Detection-1/test/images/Severity_Detect_V9_jpg.rf.705ecaf4bf0260bf683d59335b13066a.jpg: 800x800 2 severes, 9.9ms
# image 156/675 /content/datasets/Accident-Detection-1/test/images/accidentFrame108_jpg.rf.fa6fd6cf9f9678f7092460a656216fe3.jpg: 800x800 1 severe, 9.9ms
# image 157/675 /content/datasets/Accident-Detection-1/test/images/accidentFrame109_jpg.rf.d2fa3dafb7a06ad7b1b93b218c277a67.jpg: 800x800 2 severes, 9.9ms
# image 158/675 /content/datasets/Accident-Detection-1/test/images/accidentFrame112_jpg.rf.75502cbd650b704ec10cdc38ce3e73c7.jpg: 800x800 1 severe, 9.9ms
# image 159/675 /content/datasets/Accident-Detection-1/test/images/accidentFrame1191_jpg.rf.a38a74e7db2c1621efc0bc5d210129f4.jpg: 800x800 1 severe, 9.9ms
# image 160/675 /content/datasets/Accident-Detection-1/test/images/accidentFrame120_jpg.rf.1b3c7d5d8267a2e7a46ce1e125d90498.jpg: 800x800 1 severe, 9.9ms
# image 161/675 /content/datasets/Accident-Detection-1/test/images/accidentFrame120_jpg.rf.92a5f626bdc8656e9da584f7a4b04a11.jpg: 800x800 1 severe, 9.9ms
# image 162/675 /content/datasets/Accident-Detection-1/test/images/accidentFrame123_jpg.rf.7014ab40bd22ae6a95d85a0a759ad598.jpg: 800x800 1 severe, 9.9ms
# image 163/675 /content/datasets/Accident-Detection-1/test/images/accidentFrame125_jpg.rf.02200098dd8b1e0bffdaa81d234b1ea4.jpg: 800x800 1 severe, 9.9ms
# image 164/675 /content/datasets/Accident-Detection-1/test/images/accidentFrame125_jpg.rf.a6b3aab92777acb655c1ae6003021e9b.jpg: 800x800 1 severe, 9.9ms
# image 165/675 /content/datasets/Accident-Detection-1/test/images/accidentFrame126_jpg.rf.fa9e3af75d6efc4313667a24f7c9c88a.jpg: 800x800 1 severe, 9.9ms
# image 166/675 /content/datasets/Accident-Detection-1/test/images/accidentFrame128_jpg.rf.808101af1302a93785aa05fe8e0417b5.jpg: 800x800 1 severe, 9.9ms
# image 167/675 /content/datasets/Accident-Detection-1/test/images/accidentFrame128_jpg.rf.830f3c742c469630e9d4f287068eb5e8.jpg: 800x800 1 severe, 9.9ms
# image 168/675 /content/datasets/Accident-Detection-1/test/images/accidentFrame129_jpg.rf.1effb68397162ba6624e473ee53c19c6.jpg: 800x800 1 severe, 9.9ms
# image 169/675 /content/datasets/Accident-Detection-1/test/images/accidentFrame129_jpg.rf.28cb0246a2d1594436af51325d0cf757.jpg: 800x800 1 severe, 9.9ms
# image 170/675 /content/datasets/Accident-Detection-1/test/images/accidentFrame132_jpg.rf.0d3befe4227a1ad379ea9e2a183a9a5e.jpg: 800x800 1 severe, 9.9ms
# image 171/675 /content/datasets/Accident-Detection-1/test/images/accidentFrame132_jpg.rf.76fe2f93915e340c322ef06f1c4a32b1.jpg: 800x800 1 severe, 9.9ms
# image 172/675 /content/datasets/Accident-Detection-1/test/images/accidentFrame132_jpg.rf.8d742dc5f68e69b7e96e9c8666ad7aba.jpg: 800x800 1 severe, 9.9ms
# image 173/675 /content/datasets/Accident-Detection-1/test/images/accidentFrame137_jpg.rf.4ef36d3d88923c56ca66155c401e5ac7.jpg: 800x800 1 moderate, 9.9ms
# image 174/675 /content/datasets/Accident-Detection-1/test/images/accidentFrame138_jpg.rf.81daa1bca0533fce1b83df21747153cf.jpg: 800x800 1 moderate, 9.9ms
# image 175/675 /content/datasets/Accident-Detection-1/test/images/accidentFrame1852_jpg.rf.8920dc949e9ffc1edeb66b5a95e9ac56.jpg: 800x800 1 severe, 9.9ms
# image 176/675 /content/datasets/Accident-Detection-1/test/images/accidentFrame1854_jpg.rf.ebc9a8bdc68f136de5daa5cde5e1d00b.jpg: 800x800 1 severe, 9.9ms
# image 177/675 /content/datasets/Accident-Detection-1/test/images/accidentFrame2171_jpg.rf.4cf4b60df1ec6a512ad501139ff808b3.jpg: 800x800 1 severe, 9.9ms
# image 178/675 /content/datasets/Accident-Detection-1/test/images/accidentFrame2171_jpg.rf.7a9186a74b02c9302d4570d03dfc0fe9.jpg: 800x800 1 severe, 9.9ms
# image 179/675 /content/datasets/Accident-Detection-1/test/images/accidentFrame2172_jpg.rf.db34fab31a2895cdd4927099fdfe9071.jpg: 800x800 1 severe, 9.9ms
# image 180/675 /content/datasets/Accident-Detection-1/test/images/accidentFrame269_jpg.rf.35a6758ee43288bcb19f109f102b02ff.jpg: 800x800 1 severe, 9.9ms
# image 181/675 /content/datasets/Accident-Detection-1/test/images/accidentFrame269_jpg.rf.d7523dce99952a509082eb0a4582fabb.jpg: 800x800 1 severe, 9.9ms
# image 182/675 /content/datasets/Accident-Detection-1/test/images/accidentFrame2717_jpg.rf.a83820004c91f84effc27d57130c73e6.jpg: 800x800 1 severe, 9.9ms
# image 183/675 /content/datasets/Accident-Detection-1/test/images/accidentFrame2719_jpg.rf.2350f0f990f91fa8a35739b8f51f1f31.jpg: 800x800 1 severe, 9.9ms
# image 184/675 /content/datasets/Accident-Detection-1/test/images/accidentFrame2722_jpg.rf.da4024593df0506b84f8aacfefb69af7.jpg: 800x800 1 severe, 9.9ms
# image 185/675 /content/datasets/Accident-Detection-1/test/images/accidentFrame2727_jpg.rf.ce8b1cd10f55510b92c83a301d5da1dd.jpg: 800x800 2 severes, 9.9ms
# image 186/675 /content/datasets/Accident-Detection-1/test/images/accidentFrame2743_jpg.rf.080d6d0d0235881cd349294114ae10b3.jpg: 800x800 1 severe, 9.9ms
# image 187/675 /content/datasets/Accident-Detection-1/test/images/accidentFrame2744_jpg.rf.396e34eda7e60c05d550e63973ad6392.jpg: 800x800 1 severe, 9.9ms
# image 188/675 /content/datasets/Accident-Detection-1/test/images/accidentFrame2744_jpg.rf.6d81ba009acb4723c7e10e4abf0fdfc4.jpg: 800x800 1 severe, 9.9ms
# image 189/675 /content/datasets/Accident-Detection-1/test/images/accidentFrame2744_jpg.rf.809cf53dd51f0a31afa6b04874a7dee1.jpg: 800x800 1 severe, 9.9ms
# image 190/675 /content/datasets/Accident-Detection-1/test/images/accidentFrame2745_jpg.rf.ab723b11fc8739a77acc7beafe9bf32d.jpg: 800x800 1 severe, 9.9ms
# image 191/675 /content/datasets/Accident-Detection-1/test/images/accidentFrame2746_jpg.rf.016e41feab3967e6511e5cdb3aceda5c.jpg: 800x800 1 severe, 9.9ms
# image 192/675 /content/datasets/Accident-Detection-1/test/images/accidentFrame2746_jpg.rf.13b1b3fd5d2db1269763520324a165c4.jpg: 800x800 1 severe, 9.9ms
# image 193/675 /content/datasets/Accident-Detection-1/test/images/accidentFrame2747_jpg.rf.c2a1082fc81d82a0695b7c004734c7a8.jpg: 800x800 1 severe, 9.9ms
# image 194/675 /content/datasets/Accident-Detection-1/test/images/accidentFrame2749_jpg.rf.b1e8b136e8804067c7f475658cfe8979.jpg: 800x800 1 severe, 9.9ms
# image 195/675 /content/datasets/Accident-Detection-1/test/images/accidentFrame2750_jpg.rf.09e7430cd54dccf309ff2b5f3b330fb3.jpg: 800x800 1 severe, 9.9ms
# image 196/675 /content/datasets/Accident-Detection-1/test/images/accidentFrame2750_jpg.rf.98c69f2a8a39c5627594401207f117b8.jpg: 800x800 1 severe, 9.9ms
# image 197/675 /content/datasets/Accident-Detection-1/test/images/accidentFrame2751_jpg.rf.fbfb65a33dbd813f6f60fc58b54ed0bd.jpg: 800x800 1 severe, 9.9ms
# image 198/675 /content/datasets/Accident-Detection-1/test/images/accidentFrame2758_jpg.rf.5076c0d3affb5630450bad03985cce4b.jpg: 800x800 1 severe, 9.9ms
# image 199/675 /content/datasets/Accident-Detection-1/test/images/accidentFrame2759_jpg.rf.c10d038428a3e60619ff82888be2bfeb.jpg: 800x800 1 severe, 9.9ms
# image 200/675 /content/datasets/Accident-Detection-1/test/images/accidentFrame2760_jpg.rf.942407e1004e033d10bd426b8b93c728.jpg: 800x800 1 severe, 9.9ms
# image 201/675 /content/datasets/Accident-Detection-1/test/images/accidentFrame2760_jpg.rf.b1f68d03940f327ffc397a167cf3eaf9.jpg: 800x800 1 severe, 9.9ms
# image 202/675 /content/datasets/Accident-Detection-1/test/images/accidentFrame2762_jpg.rf.efcd3c6790c8bd9493d5a329821565fb.jpg: 800x800 1 severe, 10.0ms
# image 203/675 /content/datasets/Accident-Detection-1/test/images/accidentFrame281_jpg.rf.ab443b0212917be6b2aa15216aaeccf7.jpg: 800x800 1 severe, 9.9ms
# image 204/675 /content/datasets/Accident-Detection-1/test/images/accidentFrame282_jpg.rf.3efe3af26cd3c3158d2b77016fc21bd0.jpg: 800x800 1 severe, 9.9ms
# image 205/675 /content/datasets/Accident-Detection-1/test/images/accidentFrame283_jpg.rf.5eaba110effc50b40774013916cc19bb.jpg: 800x800 1 severe, 9.9ms
# image 206/675 /content/datasets/Accident-Detection-1/test/images/accidentFrame2980_jpg.rf.73ab983e5e8a1417363976b524de8189.jpg: 800x800 1 severe, 9.9ms
# image 207/675 /content/datasets/Accident-Detection-1/test/images/accidentFrame2981_jpg.rf.1f99bf61ce11bbc197d4975366db9fcd.jpg: 800x800 1 severe, 9.9ms
# image 208/675 /content/datasets/Accident-Detection-1/test/images/accidentFrame2985_jpg.rf.0dbce5be1f469afdf68746e30e1598be.jpg: 800x800 1 severe, 11.2ms
# image 209/675 /content/datasets/Accident-Detection-1/test/images/accidentFrame2985_jpg.rf.80023104f702b2d13c3dc64a5dcae48a.jpg: 800x800 1 severe, 9.9ms
# image 210/675 /content/datasets/Accident-Detection-1/test/images/accidentFrame2985_jpg.rf.e47c077f81e89384d6d231b9719dd257.jpg: 800x800 1 severe, 9.9ms
# image 211/675 /content/datasets/Accident-Detection-1/test/images/accidentFrame2994_jpg.rf.1d4098ece61a1abdb066399e99104e0f.jpg: 800x800 1 moderate, 9.9ms
# image 212/675 /content/datasets/Accident-Detection-1/test/images/accidentFrame2994_jpg.rf.a7855ff1fe37f0b19e0c1f706947deae.jpg: 800x800 1 moderate, 9.9ms
# image 213/675 /content/datasets/Accident-Detection-1/test/images/accidentFrame2996_jpg.rf.fee83ef7ba134a0c9eaa0e267a28f500.jpg: 800x800 1 moderate, 9.9ms
# image 214/675 /content/datasets/Accident-Detection-1/test/images/accidentFrame2997_jpg.rf.1f9aded0c63fefd0a5a591e03e7d016e.jpg: 800x800 1 moderate, 9.9ms
# image 215/675 /content/datasets/Accident-Detection-1/test/images/accidentFrame3002_jpg.rf.de81c9a6576e10a72e15c9a3f980a9a3.jpg: 800x800 1 moderate, 9.9ms
# image 216/675 /content/datasets/Accident-Detection-1/test/images/accidentFrame3007_jpg.rf.9c436687c160d2b84773b67a04ed2027.jpg: 800x800 1 moderate, 9.9ms
# image 217/675 /content/datasets/Accident-Detection-1/test/images/accidentFrame3007_jpg.rf.b0a0043af61a7a52f8a9cb06424cdef3.jpg: 800x800 1 moderate, 9.9ms
# image 218/675 /content/datasets/Accident-Detection-1/test/images/accidentFrame3009_jpg.rf.f8ed399ee697171e09ddc189165755ac.jpg: 800x800 1 moderate, 9.9ms
# image 219/675 /content/datasets/Accident-Detection-1/test/images/accidentFrame3012_jpg.rf.8846beecec5e6556c9f3fd1571f87abd.jpg: 800x800 1 moderate, 9.9ms
# image 220/675 /content/datasets/Accident-Detection-1/test/images/accidentFrame3014_jpg.rf.4f56584395b799d08f12ee846a2bfa89.jpg: 800x800 1 moderate, 9.9ms
# image 221/675 /content/datasets/Accident-Detection-1/test/images/accidentFrame3014_jpg.rf.cb3812b409b6664aae537132aad539d1.jpg: 800x800 1 moderate, 9.9ms
# image 222/675 /content/datasets/Accident-Detection-1/test/images/accidentFrame3016_jpg.rf.11f4d907925fd95d7678a51bc4e0d8c7.jpg: 800x800 1 moderate, 9.9ms
# image 223/675 /content/datasets/Accident-Detection-1/test/images/accidentFrame3016_jpg.rf.5413fd9413b72a118c745abae1e63cdc.jpg: 800x800 1 moderate, 9.9ms
# image 224/675 /content/datasets/Accident-Detection-1/test/images/accidentFrame3016_jpg.rf.b3ed2a4131b632b41073e0098b09c5c0.jpg: 800x800 1 moderate, 9.9ms
# image 225/675 /content/datasets/Accident-Detection-1/test/images/accidentFrame3210_jpg.rf.8bb8f408de9ed7841fbe52f2b63ee935.jpg: 800x800 1 severe, 9.9ms
# image 226/675 /content/datasets/Accident-Detection-1/test/images/accidentFrame3223_jpg.rf.94ada4ec9cf50b1e6afa1f526c4e7c10.jpg: 800x800 1 severe, 9.9ms
# image 227/675 /content/datasets/Accident-Detection-1/test/images/accidentFrame3423_jpg.rf.5ea5332067288ec8001eeef8e04f2fe0.jpg: 800x800 1 severe, 9.9ms
# image 228/675 /content/datasets/Accident-Detection-1/test/images/accidentFrame3423_jpg.rf.777440d969d57c828915a859b52fe572.jpg: 800x800 1 severe, 9.9ms
# image 229/675 /content/datasets/Accident-Detection-1/test/images/accidentFrame3424_jpg.rf.4fdb409e0200fa2befcd57ca8f392865.jpg: 800x800 1 severe, 9.9ms
# image 230/675 /content/datasets/Accident-Detection-1/test/images/accidentFrame3425_jpg.rf.6c739f4d3aab7a8e187372544cbfe8c6.jpg: 800x800 1 severe, 9.9ms
# image 231/675 /content/datasets/Accident-Detection-1/test/images/accidentFrame3426_jpg.rf.46f08b349750b6dbd4a54b21c2fc7aae.jpg: 800x800 1 severe, 9.9ms
# image 232/675 /content/datasets/Accident-Detection-1/test/images/accidentFrame3644_jpg.rf.4949699b8fd6043acd58254dae21eaf4.jpg: 800x800 1 severe, 9.9ms
# image 233/675 /content/datasets/Accident-Detection-1/test/images/accidentFrame3646_jpg.rf.f2cb262409e2559e7e822c43d8c5a3f2.jpg: 800x800 1 severe, 9.9ms
# image 234/675 /content/datasets/Accident-Detection-1/test/images/accidentFrame3648_jpg.rf.0b9a87c5cb521201af18e4264addbbf8.jpg: 800x800 1 severe, 9.9ms
# image 235/675 /content/datasets/Accident-Detection-1/test/images/accidentFrame3651_jpg.rf.b37bade5e3f8c97a3c93964c9c0de53a.jpg: 800x800 1 severe, 10.9ms
# image 236/675 /content/datasets/Accident-Detection-1/test/images/accidentFrame3948_jpg.rf.61937dc64c6fb333ec193e90e89fdd14.jpg: 800x800 1 severe, 9.9ms
# image 237/675 /content/datasets/Accident-Detection-1/test/images/accidentFrame460_jpg.rf.86ff1c6e12afd93ca5557867fa08ba81.jpg: 800x800 1 severe, 9.9ms
# image 238/675 /content/datasets/Accident-Detection-1/test/images/accidentFrame461_jpg.rf.5875737a6057d3f1a72965da4a0ae043.jpg: 800x800 1 severe, 9.9ms
# image 239/675 /content/datasets/Accident-Detection-1/test/images/accidentFrame462_jpg.rf.aeb21e0be3ef46fa51829f46e7f99032.jpg: 800x800 1 severe, 9.9ms
# image 240/675 /content/datasets/Accident-Detection-1/test/images/accidentFrame470_jpg.rf.15776d6f062295fc018870b84d0c85ef.jpg: 800x800 1 severe, 9.9ms
# image 241/675 /content/datasets/Accident-Detection-1/test/images/accidentFrame471_jpg.rf.eeaa043703f06b0eb9d680f690816270.jpg: 800x800 1 severe, 9.9ms
# image 242/675 /content/datasets/Accident-Detection-1/test/images/buy4_jpg.rf.05508a1a20ab5d1b9bbce10e179822da.jpg: 800x800 1 severe, 9.9ms
# image 243/675 /content/datasets/Accident-Detection-1/test/images/buy4_jpg.rf.2e7f32490a3b3ca1c1999e41da7bb13a.jpg: 800x800 1 severe, 9.9ms
# image 244/675 /content/datasets/Accident-Detection-1/test/images/buy6_jpg.rf.57cdfd3fd8053e7504e9950f71ea9b0f.jpg: 800x800 1 severe, 9.9ms
# image 245/675 /content/datasets/Accident-Detection-1/test/images/car_on_parked_cars_jpg.rf.617dbb9a6a8f654d47ae1ee29dd4ce5a.jpg: 800x800 2 severes, 9.9ms
# image 246/675 /content/datasets/Accident-Detection-1/test/images/car_on_parked_cars_jpg.rf.f42f8e25903dab4db2af556d7f48264e.jpg: 800x800 2 severes, 9.9ms
# image 247/675 /content/datasets/Accident-Detection-1/test/images/car_on_parked_cars_jpg.rf.fde641d09a80ee51a37578ee27a8cf80.jpg: 800x800 2 severes, 9.9ms
# image 248/675 /content/datasets/Accident-Detection-1/test/images/clarabartoncrash_jpg.rf.e758448c30da725a562895ca83421a25.jpg: 800x800 1 severe, 9.9ms
# image 249/675 /content/datasets/Accident-Detection-1/test/images/crashbetter_jpg.rf.e03eab53a144c67502c3782b2f076c41.jpg: 800x800 1 moderate, 9.9ms
# image 250/675 /content/datasets/Accident-Detection-1/test/images/download-10_jpg.rf.5d05cfcf0a3740f9c42b9da6b7e6ba23.jpg: 800x800 1 severe, 9.9ms
# image 251/675 /content/datasets/Accident-Detection-1/test/images/download-12_jpg.rf.d3d00db7f1b6250f6b0263d7eff0d307.jpg: 800x800 1 moderate, 9.9ms
# image 252/675 /content/datasets/Accident-Detection-1/test/images/download-13_jpg.rf.c9aba86dca9f58d8693131aeb4a4afc8.jpg: 800x800 1 moderate, 9.9ms
# image 253/675 /content/datasets/Accident-Detection-1/test/images/download-1_jpg.rf.2a55709c8518e7c7e982993292f7315b.jpg: 800x800 1 moderate, 9.9ms
# image 254/675 /content/datasets/Accident-Detection-1/test/images/download-1_jpg.rf.80eeeffdbc82161baced2044d6ca05ad.jpg: 800x800 1 severe, 9.9ms
# image 255/675 /content/datasets/Accident-Detection-1/test/images/download-2_jpg.rf.906a64af44f4a9023e53aaa47367cae6.jpg: 800x800 1 severe, 9.9ms
# image 256/675 /content/datasets/Accident-Detection-1/test/images/download-2_jpg.rf.bfb4559420202be7eda9cc3864b71f09.jpg: 800x800 1 severe, 9.9ms
# image 257/675 /content/datasets/Accident-Detection-1/test/images/download-2_jpg.rf.c64eb8668ce69fc62304a2ed19ce0039.jpg: 800x800 1 severe, 9.9ms
# image 258/675 /content/datasets/Accident-Detection-1/test/images/download-3_jpg.rf.2b83d474855ecd996791671a37a67376.jpg: 800x800 1 severe, 9.9ms
# image 259/675 /content/datasets/Accident-Detection-1/test/images/download-3_jpg.rf.f68b9032fe6ca1f681685b7d1616e4f7.jpg: 800x800 1 severe, 9.9ms
# image 260/675 /content/datasets/Accident-Detection-1/test/images/download-4_jpg.rf.8bb92d35c026d81318c836188597739f.jpg: 800x800 1 moderate, 9.9ms
# image 261/675 /content/datasets/Accident-Detection-1/test/images/download-5_jpg.rf.cc172d459aea4023234ba9e41df956b2.jpg: 800x800 1 severe, 9.9ms
# image 262/675 /content/datasets/Accident-Detection-1/test/images/download-7_jpg.rf.14a21e010e327ba6a18c8f9db705751b.jpg: 800x800 1 severe, 9.9ms
# image 263/675 /content/datasets/Accident-Detection-1/test/images/download-7_jpg.rf.8794a1e66b73fc8bedade61418464a9b.jpg: 800x800 1 severe, 9.9ms
# image 264/675 /content/datasets/Accident-Detection-1/test/images/download-8_jpg.rf.176b6b71fa2be480e1efa887c67bb518.jpg: 800x800 1 severe, 9.9ms
# image 265/675 /content/datasets/Accident-Detection-1/test/images/download_jpg.rf.03d95829b39b51b1deb5a6e38dbe6203.jpg: 800x800 1 severe, 9.9ms
# image 266/675 /content/datasets/Accident-Detection-1/test/images/download_jpg.rf.71bbf4d27fbbb81e720ea621e214c0f2.jpg: 800x800 1 severe, 9.9ms
# image 267/675 /content/datasets/Accident-Detection-1/test/images/download_jpg.rf.81523494878f0e11c0e9277da1acf7cb.jpg: 800x800 1 moderate, 10.1ms
# image 268/675 /content/datasets/Accident-Detection-1/test/images/images-10_jpg.rf.58c2827acf55f680bbd8d2c59b00d199.jpg: 800x800 1 severe, 9.9ms
# image 269/675 /content/datasets/Accident-Detection-1/test/images/images-10_jpg.rf.7071d4068151a22b6b512f8088abb146.jpg: 800x800 1 moderate, 9.9ms
# image 270/675 /content/datasets/Accident-Detection-1/test/images/images-10_jpg.rf.70aee8cafdcff5b3ff8a702ea256b00a.jpg: 800x800 1 severe, 9.9ms
# image 271/675 /content/datasets/Accident-Detection-1/test/images/images-10_jpg.rf.9ccd7a67a0affd252a675e9aceb3a234.jpg: 800x800 1 moderate, 9.9ms
# image 272/675 /content/datasets/Accident-Detection-1/test/images/images-10_jpg.rf.eeeff947b13e899e2c5ddabdc7d5776d.jpg: 800x800 1 severe, 9.9ms
# image 273/675 /content/datasets/Accident-Detection-1/test/images/images-11_jpg.rf.fade8a9a48f0fb1e0f66aa1bf032b3f1.jpg: 800x800 1 severe, 9.9ms
# image 274/675 /content/datasets/Accident-Detection-1/test/images/images-12_jpg.rf.1452820293358e8768aff2e29f57dbf7.jpg: 800x800 1 severe, 9.9ms
# image 275/675 /content/datasets/Accident-Detection-1/test/images/images-12_jpg.rf.47a953da1b189b94b2665e54cc8b165f.jpg: 800x800 1 severe, 9.9ms
# image 276/675 /content/datasets/Accident-Detection-1/test/images/images-12_jpg.rf.7a288ccd0b074b5c7df2c16fedc4bba3.jpg: 800x800 1 severe, 9.9ms
# image 277/675 /content/datasets/Accident-Detection-1/test/images/images-12_jpg.rf.e0b2e25b633d2f9fd49d663619b40f47.jpg: 800x800 1 severe, 9.9ms
# image 278/675 /content/datasets/Accident-Detection-1/test/images/images-13_jpg.rf.76314b5d8e2bd1d6a697649a60e0c234.jpg: 800x800 1 moderate, 9.9ms
# image 279/675 /content/datasets/Accident-Detection-1/test/images/images-13_jpg.rf.e81a3ff561d3f4573f8ef15d12c9549a.jpg: 800x800 1 severe, 9.9ms
# image 280/675 /content/datasets/Accident-Detection-1/test/images/images-16_jpg.rf.02d8b435ad277917c1767f240a41cfb8.jpg: 800x800 1 severe, 9.9ms
# image 281/675 /content/datasets/Accident-Detection-1/test/images/images-16_jpg.rf.fb3f3e680f04c291b73de65ee28a70f1.jpg: 800x800 1 severe, 9.9ms
# image 282/675 /content/datasets/Accident-Detection-1/test/images/images-17_jpg.rf.76e65a9deb7f7682b2b42348bfdedebd.jpg: 800x800 1 severe, 9.9ms
# image 283/675 /content/datasets/Accident-Detection-1/test/images/images-18_jpg.rf.3ef7b41ef42a2c5c7d7df86917b1e8ed.jpg: 800x800 1 severe, 9.9ms
# image 284/675 /content/datasets/Accident-Detection-1/test/images/images-18_jpg.rf.9cf01638c29c986ce95c15f698a626b2.jpg: 800x800 2 severes, 9.9ms
# image 285/675 /content/datasets/Accident-Detection-1/test/images/images-1_jpg.rf.0afc439e006690d7b5c45c9ec1d40ba8.jpg: 800x800 2 moderates, 9.9ms
# image 286/675 /content/datasets/Accident-Detection-1/test/images/images-1_jpg.rf.0b09a83e125fc0e279ef9e9b11554138.jpg: 800x800 1 severe, 9.9ms
# image 287/675 /content/datasets/Accident-Detection-1/test/images/images-1_jpg.rf.2f0b17a56afe8723eba611af70ce723a.jpg: 800x800 1 moderate, 9.9ms
# image 288/675 /content/datasets/Accident-Detection-1/test/images/images-1_jpg.rf.3869a07530793657c0073b81f2032e02.jpg: 800x800 1 severe, 9.9ms
# image 289/675 /content/datasets/Accident-Detection-1/test/images/images-1_jpg.rf.6ca6d9089e48a127c97806ae62fceb8b.jpg: 800x800 3 severes, 9.9ms
# image 290/675 /content/datasets/Accident-Detection-1/test/images/images-1_jpg.rf.ce33c59627406618035a5a1b470e571f.jpg: 800x800 1 severe, 9.9ms
# image 291/675 /content/datasets/Accident-Detection-1/test/images/images-1_jpg.rf.d11feaa89fd31acb1f1e755ddac4b52a.jpg: 800x800 1 moderate, 9.9ms
# image 292/675 /content/datasets/Accident-Detection-1/test/images/images-1_jpg.rf.d2f7c9d0fabd089383fb52b632f2f6e4.jpg: 800x800 1 severe, 9.9ms
# image 293/675 /content/datasets/Accident-Detection-1/test/images/images-1_jpg.rf.de5b28310afbfae273edfa910e8d851f.jpg: 800x800 1 severe, 9.9ms
# image 294/675 /content/datasets/Accident-Detection-1/test/images/images-2020-08-13T213922-238_jpg.rf.f2e81507eb6b613d7945a1ea9a1d4037.jpg: 800x800 1 severe, 9.9ms
# image 295/675 /content/datasets/Accident-Detection-1/test/images/images-2020-08-13T213923-287_jpg.rf.4bc9276ae1044b42bca263aaf2223e2a.jpg: 800x800 1 severe, 9.9ms
# image 296/675 /content/datasets/Accident-Detection-1/test/images/images-20_jpg.rf.286f8e010596d92d5f8b69b6b1f124d9.jpg: 800x800 1 severe, 11.4ms
# image 297/675 /content/datasets/Accident-Detection-1/test/images/images-21_jpg.rf.2ffb0feed31f38f3d07fd3db716e953f.jpg: 800x800 1 severe, 10.0ms
# image 298/675 /content/datasets/Accident-Detection-1/test/images/images-22_jpg.rf.0f51ee4fde24039d3771a4de46dcef71.jpg: 800x800 1 severe, 9.9ms
# image 299/675 /content/datasets/Accident-Detection-1/test/images/images-22_jpg.rf.3666818665f8a5191aafb4ee6cb52146.jpg: 800x800 1 moderate, 9.9ms
# image 300/675 /content/datasets/Accident-Detection-1/test/images/images-22_jpg.rf.3e0064ced8485fc65ba70c56dadd2c99.jpg: 800x800 1 severe, 9.9ms
# image 301/675 /content/datasets/Accident-Detection-1/test/images/images-23_jpg.rf.41b8b82e8c4514403df18ee3d17d6b58.jpg: 800x800 1 severe, 9.9ms
# image 302/675 /content/datasets/Accident-Detection-1/test/images/images-25_jpg.rf.ae2db31cea9171b47221d6f336f3a0d4.jpg: 800x800 1 severe, 9.9ms
# image 303/675 /content/datasets/Accident-Detection-1/test/images/images-26_jpg.rf.79111cbd6a170645811024a99ce249de.jpg: 800x800 1 severe, 9.9ms
# image 304/675 /content/datasets/Accident-Detection-1/test/images/images-26_jpg.rf.c92bb9e8ce5b717b1bb158e1fae9c9ef.jpg: 800x800 1 severe, 10.0ms
# image 305/675 /content/datasets/Accident-Detection-1/test/images/images-26_jpg.rf.ebd1ceb1d0ebcd2d5d9c5c01c69519ce.jpg: 800x800 1 severe, 9.9ms
# image 306/675 /content/datasets/Accident-Detection-1/test/images/images-27_jpg.rf.1ec0154e8fa093f53597a23e194fb32c.jpg: 800x800 1 severe, 9.9ms
# image 307/675 /content/datasets/Accident-Detection-1/test/images/images-28_jpg.rf.232d9cf9cb6ccf6da9160c7ee9957b39.jpg: 800x800 1 severe, 9.9ms
# image 308/675 /content/datasets/Accident-Detection-1/test/images/images-2_jpg.rf.13d9ce264edb88a785087837e3bb7668.jpg: 800x800 1 moderate, 1 severe, 10.1ms
# image 309/675 /content/datasets/Accident-Detection-1/test/images/images-2_jpg.rf.2e29633833637456eb0e976db8df0a53.jpg: 800x800 1 severe, 10.9ms
# image 310/675 /content/datasets/Accident-Detection-1/test/images/images-2_jpg.rf.5d1feebdf356482881b4d380177dadf5.jpg: 800x800 1 moderate, 3 severes, 10.0ms
# image 311/675 /content/datasets/Accident-Detection-1/test/images/images-2_jpg.rf.b063f6d3861d7edbf2d41437adbfe2b2.jpg: 800x800 1 moderate, 10.0ms
# ...
# image 571/675 /content/datasets/Accident-Detection-1/test/images/traffic_img1198_jpg.rf.4a2bc302532866ecc7d1913c579eaa92.jpg: 800x800 1 severe, 9.9ms
# image 572/675 /content/datasets/Accident-Detection-1/test/images/traffic_img1202_jpg.rf.4515be371a7982e350dcec95cc3078f6.jpg: 800x800 1 severe, 9.9ms
# image 573/675 /content/datasets/Accident-Detection-1/test/images/traffic_img1202_jpg.rf.587a5ae650976200427d81e1e111877b.jpg: 800x800 1 severe, 10.6ms
# image 574/675 /content/datasets/Accident-Detection-1/test/images/traffic_img129_jpg.rf.452237de3c2bff238caa3bd0e70300a7.jpg: 800x800 1 severe, 9.9ms
# image 575/675 /content/datasets/Accident-Detection-1/test/images/traffic_img129_jpg.rf.6cabe232f927a2af13ce355dcf07b713.jpg: 800x800 1 severe, 9.9ms
# image 576/675 /content/datasets/Accident-Detection-1/test/images/traffic_img129_jpg.rf.dd7dc4076457eac51a8e501a931356b0.jpg: 800x800 1 severe, 9.9ms
# image 577/675 /content/datasets/Accident-Detection-1/test/images/traffic_img1301_jpg.rf.3289cb100e3863ba92251e857753034a.jpg: 800x800 1 moderate, 9.9ms
# image 578/675 /content/datasets/Accident-Detection-1/test/images/traffic_img1314_jpg.rf.5a915c7d0efeb0bd6acf8c52e3d91196.jpg: 800x800 1 severe, 9.9ms
# image 579/675 /content/datasets/Accident-Detection-1/test/images/traffic_img1319_jpg.rf.1ffcf1b186e4a849b9d6a5f1c544944b.jpg: 800x800 9.9ms
# image 580/675 /content/datasets/Accident-Detection-1/test/images/traffic_img1319_jpg.rf.6116aebdce8af4fbfdfd38a314c1e00a.jpg: 800x800 9.9ms
# image 581/675 /content/datasets/Accident-Detection-1/test/images/traffic_img1346_jpg.rf.173aab1eefea191b4a18fa821e89efdd.jpg: 800x800 1 moderate, 1 severe, 9.9ms
# image 582/675 /content/datasets/Accident-Detection-1/test/images/traffic_img1346_jpg.rf.eb619764b315e52f843cdf9930dc5018.jpg: 800x800 1 severe, 9.9ms
# image 583/675 /content/datasets/Accident-Detection-1/test/images/traffic_img1347_jpg.rf.334f1f8b7b1aa08d0cdfca6799e46ea3.jpg: 800x800 1 severe, 9.9ms
# image 584/675 /content/datasets/Accident-Detection-1/test/images/traffic_img1349_jpg.rf.5bad99e54a55b1b71ad813a31133bacd.jpg: 800x800 1 severe, 9.9ms
# image 585/675 /content/datasets/Accident-Detection-1/test/images/traffic_img1371_jpg.rf.14b004907b6d40a3d4537dbc8468b372.jpg: 800x800 1 moderate, 1 severe, 9.9ms
# image 586/675 /content/datasets/Accident-Detection-1/test/images/traffic_img1392_jpg.rf.08c0f144d816a9425885bf9547b46abc.jpg: 800x800 1 severe, 9.9ms
# image 587/675 /content/datasets/Accident-Detection-1/test/images/traffic_img1468_jpg.rf.a5dec26f7d98e1fc8909d5442460dccf.jpg: 800x800 1 moderate, 1 severe, 9.9ms
# image 588/675 /content/datasets/Accident-Detection-1/test/images/traffic_img1472_jpg.rf.8a57519b1fadcdfc6131141161dd179f.jpg: 800x800 1 moderate, 9.9ms
# image 589/675 /content/datasets/Accident-Detection-1/test/images/traffic_img1483_jpg.rf.1d2be775bd41e3075a77442c4809e869.jpg: 800x800 1 moderate, 9.9ms
# image 590/675 /content/datasets/Accident-Detection-1/test/images/traffic_img1527_jpg.rf.27704c69f867c3eff2f69fd8ba793f9e.jpg: 800x800 1 moderate, 9.9ms
# image 591/675 /content/datasets/Accident-Detection-1/test/images/traffic_img1551_jpg.rf.21fc39bb0aaaa3fcd6fabb2fe825e7a4.jpg: 800x800 2 severes, 9.9ms
# image 592/675 /content/datasets/Accident-Detection-1/test/images/traffic_img1552_jpg.rf.ce857510d904992658f90d16d9f96530.jpg: 800x800 1 severe, 9.9ms
# image 593/675 /content/datasets/Accident-Detection-1/test/images/traffic_img1558_jpg.rf.0f8bf38267c0554b11ce6fda7abdddeb.jpg: 800x800 1 severe, 9.9ms
# image 594/675 /content/datasets/Accident-Detection-1/test/images/traffic_img1579_jpg.rf.6ae60db646b4398c262a8e4ee1f59f14.jpg: 800x800 1 severe, 9.9ms
# image 595/675 /content/datasets/Accident-Detection-1/test/images/traffic_img1595_jpg.rf.13433b6f3fdfe0807d5814d3f94c439a.jpg: 800x800 1 moderate, 1 severe, 9.9ms
# image 596/675 /content/datasets/Accident-Detection-1/test/images/traffic_img1596_jpg.rf.b0d031424771a37e5811750e89f21a36.jpg: 800x800 1 moderate, 9.9ms
# image 597/675 /content/datasets/Accident-Detection-1/test/images/traffic_img1596_jpg.rf.bad80b563250e9ae8f1c637033057b26.jpg: 800x800 1 moderate, 10.0ms
# image 598/675 /content/datasets/Accident-Detection-1/test/images/traffic_img1596_jpg.rf.f38baad0d63b85e1d3b5d4da1bb90b03.jpg: 800x800 1 moderate, 9.9ms
# image 599/675 /content/datasets/Accident-Detection-1/test/images/traffic_img16_jpg.rf.49151869e27b5453e3a49e0a5b254a5c.jpg: 800x800 1 severe, 9.9ms
# image 600/675 /content/datasets/Accident-Detection-1/test/images/traffic_img1765_jpg.rf.1c4c40a8db54ee9cb493bb5bfd848f3d.jpg: 800x800 1 severe, 9.9ms
# image 601/675 /content/datasets/Accident-Detection-1/test/images/traffic_img17_jpg.rf.8f44e3eab921c4810052d52960bf862c.jpg: 800x800 1 severe, 9.9ms
# image 602/675 /content/datasets/Accident-Detection-1/test/images/traffic_img1803_jpg.rf.68db540c414c058bb22b87e756a6f1ec.jpg: 800x800 1 moderate, 1 severe, 9.9ms
# image 603/675 /content/datasets/Accident-Detection-1/test/images/traffic_img1803_jpg.rf.7ba98c14082261fa405898d27eec983f.jpg: 800x800 10.1ms
# image 604/675 /content/datasets/Accident-Detection-1/test/images/traffic_img1805_jpg.rf.efa976826bc499176bcb167efa586a39.jpg: 800x800 9.9ms
# image 605/675 /content/datasets/Accident-Detection-1/test/images/traffic_img1807_jpg.rf.502d44b5efbfbea85a7999d9eb2b0489.jpg: 800x800 1 moderate, 9.9ms
# image 606/675 /content/datasets/Accident-Detection-1/test/images/traffic_img180_jpg.rf.5d5a351d88cf13e883f494e0a02f09a3.jpg: 800x800 1 severe, 11.3ms
# image 607/675 /content/datasets/Accident-Detection-1/test/images/traffic_img1810_jpg.rf.8d9d993390de001693286d9ba625f0ae.jpg: 800x800 1 severe, 9.9ms
# image 608/675 /content/datasets/Accident-Detection-1/test/images/traffic_img1810_jpg.rf.b553ee7eb9d1a3b30d4921c09a0d31ee.jpg: 800x800 9.9ms
# image 609/675 /content/datasets/Accident-Detection-1/test/images/traffic_img1811_jpg.rf.ab7d77c8a2456ddf4c54f4bbbf161671.jpg: 800x800 1 moderate, 9.9ms
# image 610/675 /content/datasets/Accident-Detection-1/test/images/traffic_img1818_jpg.rf.7938159322aba17bd41b5dfcd87d187d.jpg: 800x800 2 moderates, 9.9ms
# image 611/675 /content/datasets/Accident-Detection-1/test/images/traffic_img185_jpg.rf.ab24ec4cacd4e828a7087ee7a6d907cf.jpg: 800x800 1 moderate, 1 severe, 9.9ms
# image 612/675 /content/datasets/Accident-Detection-1/test/images/traffic_img185_jpg.rf.ff843c914abde1a61ce5e334f4f2b3e6.jpg: 800x800 1 moderate, 1 severe, 9.9ms
# image 613/675 /content/datasets/Accident-Detection-1/test/images/traffic_img1884_jpg.rf.23f141ffb1ba17b09d2556c53094fa00.jpg: 800x800 1 severe, 9.9ms
# image 614/675 /content/datasets/Accident-Detection-1/test/images/traffic_img1887_jpg.rf.2c626d6c0e9f524c93c32ba5305f5442.jpg: 800x800 1 severe, 9.9ms
# image 615/675 /content/datasets/Accident-Detection-1/test/images/traffic_img1887_jpg.rf.67aaf15a18548e9cf06566065a88b063.jpg: 800x800 1 severe, 9.9ms
# image 616/675 /content/datasets/Accident-Detection-1/test/images/traffic_img194_jpg.rf.89c5cc322ec45d0b9e12e8a59450fabc.jpg: 800x800 2 moderates, 9.9ms
# image 617/675 /content/datasets/Accident-Detection-1/test/images/traffic_img2115_jpg.rf.335654e1adcc2bc5550d41c7202e996d.jpg: 800x800 2 moderates, 9.9ms
# image 618/675 /content/datasets/Accident-Detection-1/test/images/traffic_img2121_jpg.rf.7c2dad86ad7a29dff3e2ac278cd2807d.jpg: 800x800 1 severe, 9.9ms
# image 619/675 /content/datasets/Accident-Detection-1/test/images/traffic_img2121_jpg.rf.b4c6b735a8b16db4046c683b865cf007.jpg: 800x800 1 severe, 9.9ms
# image 620/675 /content/datasets/Accident-Detection-1/test/images/traffic_img215_jpg.rf.5e750e4c864b67b7705e426b3fcdad9e.jpg: 800x800 1 moderate, 9.9ms
# image 621/675 /content/datasets/Accident-Detection-1/test/images/traffic_img21_jpg.rf.b5eb0279f78a762f34a68af6bab19285.jpg: 800x800 1 severe, 9.9ms
# image 622/675 /content/datasets/Accident-Detection-1/test/images/traffic_img25_jpg.rf.e779a7157afc6447bc2c5ed598ae6acb.jpg: 800x800 1 severe, 9.9ms
# image 623/675 /content/datasets/Accident-Detection-1/test/images/traffic_img282_jpg.rf.eb7f25f8448b93e2a58e6ce4416a8abb.jpg: 800x800 1 moderate, 1 severe, 9.9ms
# image 624/675 /content/datasets/Accident-Detection-1/test/images/traffic_img28_jpg.rf.1af5758b0078426375b229550d4f810b.jpg: 800x800 1 severe, 9.9ms
# image 625/675 /content/datasets/Accident-Detection-1/test/images/traffic_img292_jpg.rf.3a04c0e61501def888bb906f6f17e588.jpg: 800x800 1 moderate, 9.9ms
# image 626/675 /content/datasets/Accident-Detection-1/test/images/traffic_img292_jpg.rf.8027429e8dea6c32e859f27b804a4b70.jpg: 800x800 1 severe, 9.9ms
# image 627/675 /content/datasets/Accident-Detection-1/test/images/traffic_img331_jpg.rf.7b9d723a50e725ec9d1c560f310fca0b.jpg: 800x800 1 moderate, 1 severe, 9.9ms
# image 628/675 /content/datasets/Accident-Detection-1/test/images/traffic_img343_jpg.rf.6bd1b3a84700f53119bffd86a4348495.jpg: 800x800 1 moderate, 9.9ms
# image 629/675 /content/datasets/Accident-Detection-1/test/images/traffic_img419_jpg.rf.a2656e22a2f849ff99f699df5f222167.jpg: 800x800 1 moderate, 9.9ms
# image 630/675 /content/datasets/Accident-Detection-1/test/images/traffic_img421_jpg.rf.7f8164d719b9d4b0ce30129bd695e849.jpg: 800x800 1 severe, 9.9ms
# image 631/675 /content/datasets/Accident-Detection-1/test/images/traffic_img425_jpg.rf.85807dae946c4c8a041d4bc85822065f.jpg: 800x800 1 severe, 9.9ms
# image 632/675 /content/datasets/Accident-Detection-1/test/images/traffic_img425_jpg.rf.9cc55f45333c8ca584606b127448d18e.jpg: 800x800 1 severe, 9.9ms
# image 633/675 /content/datasets/Accident-Detection-1/test/images/traffic_img447_jpg.rf.ad0b91828ff7718e143cbafcd8c48338.jpg: 800x800 1 moderate, 9.9ms
# image 634/675 /content/datasets/Accident-Detection-1/test/images/traffic_img476_jpg.rf.31414c05d6a00225d5a39f212c540da4.jpg: 800x800 1 moderate, 1 severe, 9.9ms
# image 635/675 /content/datasets/Accident-Detection-1/test/images/traffic_img477_jpg.rf.d6407a5fae199589182217f7cbb4d0c7.jpg: 800x800 1 severe, 9.9ms
# image 636/675 /content/datasets/Accident-Detection-1/test/images/traffic_img531_jpg.rf.8cd3be2c32737d14eaf674ac01aa2084.jpg: 800x800 1 severe, 9.9ms
# image 637/675 /content/datasets/Accident-Detection-1/test/images/traffic_img53_jpg.rf.67085fa80eea97a0eb6322b33fadaf36.jpg: 800x800 1 severe, 9.9ms
# image 638/675 /content/datasets/Accident-Detection-1/test/images/traffic_img53_jpg.rf.d38a192c51cc35d778b5fca3be3f819f.jpg: 800x800 1 severe, 9.9ms
# image 639/675 /content/datasets/Accident-Detection-1/test/images/traffic_img566_jpg.rf.36eafe066315f3b16042e3a9b0e69181.jpg: 800x800 1 moderate, 9.9ms
# image 640/675 /content/datasets/Accident-Detection-1/test/images/traffic_img57_jpg.rf.90a16e23447c5a650190019228eb26d7.jpg: 800x800 1 severe, 9.9ms
# image 641/675 /content/datasets/Accident-Detection-1/test/images/traffic_img586_jpg.rf.49dd0221b6f41028b423d297b3a91065.jpg: 800x800 1 moderate, 9.9ms
# image 642/675 /content/datasets/Accident-Detection-1/test/images/traffic_img58_jpg.rf.e6eaae926a2f703c34989a02a8665140.jpg: 800x800 1 severe, 9.9ms
# image 643/675 /content/datasets/Accident-Detection-1/test/images/traffic_img607_jpg.rf.7e45507366048f1c6051263c16a7a2da.jpg: 800x800 1 severe, 9.9ms
# image 644/675 /content/datasets/Accident-Detection-1/test/images/traffic_img607_jpg.rf.bc9b23b2674a6dedeee72a0a16c039dc.jpg: 800x800 1 severe, 9.9ms
# image 645/675 /content/datasets/Accident-Detection-1/test/images/traffic_img61_jpg.rf.230f040c79b81260338b932870c6f4db.jpg: 800x800 1 severe, 9.9ms
# image 646/675 /content/datasets/Accident-Detection-1/test/images/traffic_img649_jpg.rf.97bb4c925e6c118792e9e12753712bbc.jpg: 800x800 1 moderate, 9.9ms
# image 647/675 /content/datasets/Accident-Detection-1/test/images/traffic_img649_jpg.rf.9d117ac050fac89cd47d85d6ee79b3ac.jpg: 800x800 1 moderate, 9.9ms
# image 648/675 /content/datasets/Accident-Detection-1/test/images/traffic_img655_jpg.rf.f28fe207661dbe6af4f3214c364605e0.jpg: 800x800 1 severe, 9.9ms
# image 649/675 /content/datasets/Accident-Detection-1/test/images/traffic_img668_jpg.rf.5b76d9ac056fc043851c79e140e8ec0c.jpg: 800x800 9.9ms
# image 650/675 /content/datasets/Accident-Detection-1/test/images/traffic_img67_jpg.rf.58060c9160413f1b91950b498e858551.jpg: 800x800 1 severe, 9.9ms
# image 651/675 /content/datasets/Accident-Detection-1/test/images/traffic_img688_jpg.rf.1e3a0748b311c8ffccd549d35cde1c73.jpg: 800x800 2 moderates, 9.9ms
# image 652/675 /content/datasets/Accident-Detection-1/test/images/traffic_img690_jpg.rf.46698f1e66903dc19bffba8790a25e57.jpg: 800x800 2 severes, 9.9ms
# image 653/675 /content/datasets/Accident-Detection-1/test/images/traffic_img703_jpg.rf.b601a33269b09207757a4f31f56199b9.jpg: 800x800 1 moderate, 1 severe, 9.9ms
# image 654/675 /content/datasets/Accident-Detection-1/test/images/traffic_img741_jpg.rf.b9b9e2efa907dd8e7527bc51782d4772.jpg: 800x800 2 moderates, 9.9ms
# image 655/675 /content/datasets/Accident-Detection-1/test/images/traffic_img779_jpg.rf.474bbd5141ec9a9bde4b81b11dfc9db8.jpg: 800x800 1 moderate, 9.9ms
# image 656/675 /content/datasets/Accident-Detection-1/test/images/traffic_img779_jpg.rf.95b27bf4568851ca1bb67805b24b329e.jpg: 800x800 1 moderate, 9.9ms
# image 657/675 /content/datasets/Accident-Detection-1/test/images/traffic_img779_jpg.rf.c11005aa49b58ebb62623c0a48418f06.jpg: 800x800 1 moderate, 9.9ms
# image 658/675 /content/datasets/Accident-Detection-1/test/images/traffic_img780_jpg.rf.362feef582ff7ef4d36430e5b6f65b96.jpg: 800x800 1 moderate, 9.9ms
# image 659/675 /content/datasets/Accident-Detection-1/test/images/traffic_img780_jpg.rf.bbed7028a90bcf6cc17891ba7569394d.jpg: 800x800 1 moderate, 9.9ms
# image 660/675 /content/datasets/Accident-Detection-1/test/images/traffic_img781_jpg.rf.9dd85ae130aa736633dbbff3f83f5ffa.jpg: 800x800 1 moderate, 9.9ms
# image 661/675 /content/datasets/Accident-Detection-1/test/images/traffic_img801_jpg.rf.15a87b7e6ebe9201ecd48432472c4460.jpg: 800x800 2 severes, 9.9ms
# image 662/675 /content/datasets/Accident-Detection-1/test/images/traffic_img803_jpg.rf.2fd6adb9cd0b20824cf52d3f9be8fd08.jpg: 800x800 1 severe, 9.9ms
# image 663/675 /content/datasets/Accident-Detection-1/test/images/traffic_img803_jpg.rf.e6ecb6f141593b9ba5041deb56312898.jpg: 800x800 1 severe, 9.9ms
# image 664/675 /content/datasets/Accident-Detection-1/test/images/traffic_img805_jpg.rf.a221abdf0ee131aa63586e767693b18a.jpg: 800x800 1 severe, 9.9ms
# image 665/675 /content/datasets/Accident-Detection-1/test/images/traffic_img870_jpg.rf.79bcde74ba4eb709cc0d9699c0ed5bd5.jpg: 800x800 1 moderate, 9.9ms
# image 666/675 /content/datasets/Accident-Detection-1/test/images/traffic_img8_jpg.rf.a668d814c8c9d31ba70f2613e1a5b55b.jpg: 800x800 1 severe, 9.9ms
# image 667/675 /content/datasets/Accident-Detection-1/test/images/traffic_img932_jpg.rf.dbd7e71bb942671731f4915826f5a3ee.jpg: 800x800 1 severe, 9.9ms
# image 668/675 /content/datasets/Accident-Detection-1/test/images/traffic_img991_jpg.rf.44cdd302cc61eb2001a440b16049688c.jpg: 800x800 1 moderate, 9.9ms
# image 669/675 /content/datasets/Accident-Detection-1/test/images/traffic_img99_jpg.rf.0cedfc4099b58f48f097a76378eac6a1.jpg: 800x800 1 severe, 9.9ms
# image 670/675 /content/datasets/Accident-Detection-1/test/images/tt1-v2_jpg.rf.eaf646d6ed513025c8598ed8c84bf531.jpg: 800x800 2 severes, 9.9ms
# image 671/675 /content/datasets/Accident-Detection-1/test/images/tt1-v4_jpg.rf.beb6476065c5c185cb24e98e3ed43589.jpg: 800x800 2 severes, 9.9ms
# image 672/675 /content/datasets/Accident-Detection-1/test/images/vd100_jpeg_jpg.rf.7ea23ddb8fb988f73873a25fc5597585.jpg: 800x800 1 severe, 9.9ms
# image 673/675 /content/datasets/Accident-Detection-1/test/images/vd13_png_jpg.rf.745218192773f63921f718012515480f.jpg: 800x800 9.9ms
# image 674/675 /content/datasets/Accident-Detection-1/test/images/vd13_png_jpg.rf.cffc6684868324df352f5c0e654e70ac.jpg: 800x800 9.9ms
# image 675/675 /content/datasets/Accident-Detection-1/test/images/vd55_jpeg_jpg.rf.427e6919da57735233394537dc979cfb.jpg: 800x800 1 moderate, 1 severe, 9.9ms
# Speed: 0.7ms pre-process, 10.0ms inference, 1.6ms postprocess per image at shape (1, 3, 800, 800)
# Results saved to runs/detect/predict

# %% [markdown]
# **NOTE:** Let's take a look at few results.

# %%
# !zip -r /content/datasets/runs.Zip /content/datasets/runs/
# Out:
#   adding: content/datasets/runs/ (stored 0%)
#   adding: content/datasets/runs/detect/ (stored 0%)
#   adding: content/datasets/runs/detect/train2/ (stored 0%)
#   adding: content/datasets/runs/detect/train2/val_batch2_labels.jpg (deflated 7%)
#   adding: content/datasets/runs/detect/train2/val_batch0_labels.jpg (deflated 5%)
#   adding: content/datasets/runs/detect/train2/val_batch0_pred.jpg (deflated 5%)
#   adding: content/datasets/runs/detect/train2/R_curve.png (deflated 11%)
#   adding: content/datasets/runs/detect/train2/val_batch2_pred.jpg (deflated 6%)
#   adding: content/datasets/runs/detect/train2/train_batch0.jpg (deflated 7%)
#   adding: content/datasets/runs/detect/train2/train_batch1.jpg (deflated 5%)
#   adding: content/datasets/runs/detect/train2/F1_curve.png (deflated 10%)
#   adding: content/datasets/runs/detect/train2/val_batch1_pred.jpg (deflated 6%)
#   adding: content/datasets/runs/detect/train2/confusion_matrix.png (deflated 32%)
#   adding: content/datasets/runs/detect/train2/val_batch1_labels.jpg (deflated 6%)
#   adding: content/datasets/runs/detect/train2/args.yaml (deflated 50%)
#   adding: content/datasets/runs/detect/train2/train_batch2.jpg (deflated 7%)
#   adding: content/datasets/runs/detect/train2/results.csv (deflated 82%)
#   adding: content/datasets/runs/detect/train2/PR_curve.png (deflated 14%)
#   adding: content/datasets/runs/detect/train2/events.out.tfevents.1699106165.a367f68a2a70.1638.0 (deflated 72%)
#   adding: content/datasets/runs/detect/train2/results.png (deflated 9%)
#   adding: content/datasets/runs/detect/train2/P_curve.png (deflated 12%)
#   adding: content/datasets/runs/detect/train2/weights/ (stored 0%)
#   adding: content/datasets/runs/detect/train2/weights/best.pt (deflated 10%)
#   adding: content/datasets/runs/detect/train2/weights/last.pt (deflated 10%)
#   adding: content/datasets/runs/detect/train/ (stored 0%)
#   adding: content/datasets/runs/detect/train/events.out.tfevents.1699106018.a367f68a2a70.964.0 (deflated 9%)
#   adding: content/datasets/runs/detect/train/args.yaml (deflated 50%)
#   adding: content/datasets/runs/detect/train/weights/ (stored 0%)

# %% [markdown]
# # Accident detection

# %%
# !nvidia-smi
# Out:
# Sun Nov  5 09:35:59 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.105.17   Driver Version: 525.105.17   CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   36C    P8     9W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
import os
HOME = os.getcwd()
print(HOME)
# Out:
# /content

# %% [markdown]
# ## Download

# %%
# !pip install -q gdown
# %cd {HOME}
# !gdown '1wPYpRYZuSTFO2og94C2MshhJMwRRfNwu'
# !gdown '1F4WGIxvbB-nGnyPwPDxoYL1XOQtiRWxl'
# !gdown '1bIGGtyg9ly9Je9nSN7tK5MkcGQ7tHasa'
# !gdown '1viV_4cP0nwfxxLrquQf9e-c7SVWlmAOb'
# Out:
# /content
# Downloading...
# From: https://drive.google.com/uc?id=1wPYpRYZuSTFO2og94C2MshhJMwRRfNwu
# To: /content/Accident.mp4
# 100% 67.9M/67.9M [00:00<00:00, 169MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1F4WGIxvbB-nGnyPwPDxoYL1XOQtiRWxl
# To: /content/vid.mp4
# 100% 1.82M/1.82M [00:00<00:00, 228MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1bIGGtyg9ly9Je9nSN7tK5MkcGQ7tHasa
# To: /content/best.pt
# 100% 6.27M/6.27M [00:00<00:00, 192MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1viV_4cP0nwfxxLrquQf9e-c7SVWlmAOb
# To: /content/vid2.mp4
# 100% 171M/171M [00:03<00:00, 48.9MB/s]

# %%
SOURCE_VIDEO_PATH = "/content/vid2.mp4"

# %% [markdown]
# ## Install YOLOv8
#
# If you notice that our notebook behaves incorrectly - especially if you experience errors that prevent you from going through the tutorial - don't hesitate! Let us know and open an [issue](https://github.com/roboflow/notebooks/issues) on the Roboflow Notebooks repository.

# %%
# !pip install ultralytics

from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.206 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 27.3/78.2 GB disk)

# %% [markdown]
# ## Install Roboflow Supervision

# %%
# !pip install supervision

from IPython import display
display.clear_output()

import supervision as sv
print("supervision.__version__:", sv.__version__)
# Out:
# supervision.__version__: 0.16.0

# %% [markdown]
# ## Load pre-trained YOLOv8 model

# %%
MODEL = "/content/best.pt"

# %%
from ultralytics import YOLO

model = YOLO(MODEL)
model.fuse()
# Out:
# Model summary (fused): 168 layers, 3006038 parameters, 0 gradients, 8.1 GFLOPs

# %% [markdown]
# ## Predict and annotate single frame

# %%
# dict maping class_id to class_name
CLASS_NAMES_DICT = model.model.names

# class_ids of interest - moderate, severe
selected_classes = [0,1]

# %%
import supervision as sv
import numpy as np

# %%
# create frame generator
generator = sv.get_video_frames_generator(SOURCE_VIDEO_PATH)
# create instance of BoxAnnotator
box_annotator = sv.BoxAnnotator(thickness=2, text_thickness=2, text_scale=1)
# acquire first video frame
iterator = iter(generator)
frame = next(iterator)
# model prediction on single frame and conversion to supervision Detections
results = model(frame, verbose=False)[0]

# convert to Detections
detections = sv.Detections.from_ultralytics(results)
# only consider class id from selected_classes define above
detections = detections[np.isin(detections.class_id, selected_classes)]

# format custom labels
labels = [
    f"{CLASS_NAMES_DICT[class_id]} {confidence:0.2f}"
    for _, _, confidence, class_id, _ in detections
]

# annotate and display frame
anotated_frame=box_annotator.annotate(scene=frame, detections=detections, labels=labels)

# %matplotlib inline
sv.plot_image(anotated_frame, (16,16))

# %% [markdown]
# ## Predict and annotate whole video

# %%
# settings
LINE_START = sv.Point(50, 1500)
LINE_END = sv.Point(3840-50, 1500)

TARGET_VIDEO_PATH = "/content/sample2.mp4"

# %%
sv.VideoInfo.from_video_path(SOURCE_VIDEO_PATH)
# Out:
# VideoInfo(width=1920, height=1080, fps=30, total_frames=2145)

# %%
# create BYTETracker instance
byte_tracker = sv.ByteTrack(track_thresh=0.25, track_buffer=30, match_thresh=0.8, frame_rate=30)

# create VideoInfo instance
video_info = sv.VideoInfo.from_video_path(SOURCE_VIDEO_PATH)

# create frame generator
generator = sv.get_video_frames_generator(SOURCE_VIDEO_PATH)

# create LineZone instance, it is previously called LineCounter class
line_zone = sv.LineZone(start=LINE_START, end=LINE_END)

# create instance of BoxAnnotator
box_annotator = sv.BoxAnnotator(thickness=2, text_thickness=2, text_scale=1)

# create instance of TraceAnnotator
trace_annotator = sv.TraceAnnotator(thickness=4, trace_length=50)

# create LineZoneAnnotator instance, it is previously called LineCounterAnnotator class
line_zone_annotator = sv.LineZoneAnnotator(thickness=2, text_thickness=2, text_scale=1)

# define call back function to be used in video processing
def callback(frame: np.ndarray, index:int) -> np.ndarray:
    # model prediction on single frame and conversion to supervision Detections
    results = model(frame, verbose=False)[0]
    detections = sv.Detections.from_ultralytics(results)
    # only consider class id from selected_classes define above
    detections = detections[np.isin(detections.class_id, selected_classes)]
    # tracking detections
    detections = byte_tracker.update_with_detections(detections)
    labels = [
        f"#{tracker_id} {model.model.names[class_id]} {confidence:0.2f}"
        for _, _, confidence, class_id, tracker_id
        in detections
    ]
    annotated_frame = trace_annotator.annotate(
        scene=frame.copy(),
        detections=detections
    )
    annotated_frame=box_annotator.annotate(
        scene=annotated_frame,
        detections=detections,
        labels=labels)

    # update line counter
    line_zone.trigger(detections)
    # return frame with box and line annotated result
    return  line_zone_annotator.annotate(annotated_frame, line_counter=line_zone)

# process the whole video
sv.process_video(
    source_path = SOURCE_VIDEO_PATH,
    target_path = TARGET_VIDEO_PATH,
    callback=callback
)
